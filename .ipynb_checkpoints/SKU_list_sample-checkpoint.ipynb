# %% [markdown]
# ## SKU Creation

# %% [markdown]
# 1. Isolate the product within the options dataframe with all their options.
# 2. Fill nulls using ffill method
# 3. Compile list of options using the optionid
# 4. Generate all combinations
# 5. Create new dataframe of options
# 6. Generate SKUs based on those combinations.
#
# ## Business Problem:
# As per my conversaƟon with Allen Shimon, StrobesnMore needs a merge of their products and product
# opƟons so that every possible combinaƟon of opƟons has a unique skew. The challenge that their
# website currently faces is that their inventory lookup requires visiƟng mulƟple links and clicking into
# mulƟple dropdowns, making their current list ineffecƟve at looking up product quickly.
#
# Example:
# Product 123 has 2 options with multiple types.
# Option 1(product feature): Magnetic VS Permanent
# Option 2(color): Blue VS Green
#
# CURRENTLY: Product 123 only has 1 skew (123)
# After the complete skew list is created, the following skews will be provided:
# 123MBLUE
# 123PBLUE
# 123MGREEN
# 123PGREEN
#
#
# ## Data Understanding
# Two csv files were provided to demonstrate the need for this service. There is a csv with a full list of
# products and another with a list of product options. The goal will be to provide a query merging these
# two csv files so that each product has a skew associated with every combination of options associated
# with it.
# This process will require “digging into” the data and coding a query to pull the list of products and merge
# all their combination of options. To ensure quality, an understanding of the data options and their
# products will be required.
# In the product options list, a few observations have been made and need to be confirmed…
# 1. It is assumed that each product can only have one unique color.
# 2. The optionid is the identifier for the option categories for each product. It is assumed that each
# product can only have one unique option (for example, cannot be both magnetic and permanent) per
# optionid.
# 4. The catalogid, NOT the productid in the csv appears to the proper unique identifier for each product.
# 5. Client should list if there is a preffered format for SKU creation(color first, capitals, etc)

# %% [markdown]
# Challenges
#
# Making this iterative process work on all products(There are 1200. Unless I want to spend 60 hours, that would take a while.)

# %% [markdown]
# # EDA

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", 100)

# %%
df_prod = pd.read_csv('products.csv', encoding='unicode_escape')
len(df_prod)
# Out:
# 1277

# %% [markdown]
# ### Checking the products
#
# This is a simple check of the product list, mainly to see if there are any duplicates.

# %%
df_prod['name'].duplicated().value_counts()
# Out:
# False    1254
# True       23
# Name: name, dtype: int64

# %%
df_prod[df_prod["id"].duplicated()].head(10)
# Out:
#      catalogid     id  \
# 11        3486     50
# 12        3487     68
# 14        3490     68
# 17        3493     68
# 20        3496     68
# 81        3754     40
# 340       5401     M9
# 366       5431  CCSRN
# 380       5462     AV
# 381       5463     AV
#
#                                                                            name  \
# 11                                            Whelen 500 Series TIR6 Super-LED
# 12                       Whelen 500 Series Lens for LED and Halogen with Optics
# 14                                                       Whelen 600 Series Lens
# 17                                                 Whelen 700 Series Optic Lens
# 20                                                 Whelen 900 Series Optic Lens
# 81                                     Whelen 400 Series Single Level Super-LED
# 340                           Whelen M9 Conversion Flange from M9 to 900 Series
# 366                              Whelen CenCom Carbide Amplifier Control Module
# 380    Whelen Avenger II DUO Single Combination Linear/TIR Super-LED Dash Light
# 381  Whelen Avenger II TRIO Single Combination Linear/TIR Super-LED Dash Light
#
#                                                           image1  \
# 11              assets/images/whelen-500-tir6-lighthead-blue.jpg
# 12   assets/images/whelen-replacement-500-lens-halogen-optic.jpg
# 14   assets/images/whelen-replacement-600-lens-halogen-optic.jpg
# 17   assets/images/whelen-replacement-700-lens-halogen-optic.jpg
# 20              assets/images/Whelen_900Series_OpticLens_Red.jpg
# 81     assets/images/whelen-400-series-singe-level-led-amber.jpg
# 340                                    assets/images/M9FC900.jpg
# 366                                assets/images/carbide-grp.jpg
# 380                               assets/images/AVENGERIIDUO.jpg
# 381                              assets/images/AVENGERIITRIO.jpg
#
#                                                                             thumbnail  \
# 11       assets/images/thumbnails/whelen-500-tir6-black-flange-5flangeb_thumbnail.jpg
# 12   assets/images/thumbnails/whelen-replacement-500-lens-halogen-optic_thumbnail.jpg
# 14   assets/images/thumbnails/whelen-replacement-600-lens-halogen-optic_thumbnail.jpg
# 17   assets/images/thumbnails/whelen-replacement-700-lens-halogen-optic_thumbnail.jpg
# 20              assets/images/thumbnails/Whelen_900Series_OpticLens_Red_thumbnail.jpg
# 81     assets/images/thumbnails/whelen-400-series-singe-level-led-amber_thumbnail.jpg
# 340                                    assets/images/thumbnails/m9fc900_thumbnail.jpg
# 366                                assets/images/thumbnails/carbide-grp_thumbnail.jpg
# 380                               assets/images/thumbnails/avengeriiduo_thumbnail.jpg
# 381                              assets/images/thumbnails/avengeriitrio_thumbnail.jpg
#
#        price                                     categories  \
# 11    139.99                LED Lights/Body & Grille Mount
# 12     39.99  Replacement Bulbs & Lenses/Replacement Lenses
# 14     76.99  Replacement Bulbs & Lenses/Replacement Lenses
# 17     77.99  Replacement Bulbs & Lenses/Replacement Lenses
# 20     77.99  Replacement Bulbs & Lenses/Replacement Lenses
# 81    110.99                LED Lights/Body & Grille Mount
# 340    41.99     LED Lights/Mounting Brackets & Accessories
# 366  1197.99          Sirens & Speakers/Sirens & Amplifiers
# 380   182.99                 LED Lights/Dash & Window Mount
# 381   194.99                 LED Lights/Dash & Window Mount
#
#                                                                                              description  \
# 11   These lightheads feature a six Super-LED panel, three Super-LEDs per color, in a single lighthea...
# 12   These are Whelen 500 Series replacement lenses. Please choose optic, which has the groves in the...
# 14                                             These Whelen 600 Series lenses fit the below lightheads.
# 17                                    These Whelen 700 Series lenses fit the 700 Series LED lightheads.
# 20                                These Whelen replacement lens fit the 900 Series Super-Led lightheads.
# 81   Whelen's Super Linear 400 Series lightheads feature 5 built in scan-lcok flash patterns and are ...
# 340                                                                                                  NaN
# 366                                                                                                  NaN
# 380                                                                                                  NaN
# 381                                                                                                  NaN
#
#     keywords    stock
# 11       NaN   9930.0
# 12       NaN    -79.0
# 14       NaN    -97.0
# 17       NaN   -104.0
# 20       NaN   -187.0
# 81       NaN  33977.0
# 340      NaN     -8.0
# 366      NaN    -35.0
# 380      NaN    -13.0
# 381      NaN     -6.0

# %%
df_prod['name'].duplicated().sort_values(ascending=False).head(10)
# Out:
# 638    True
# 491    True
# 511    True
# 582    True
# 607    True
# 774    True
# 917    True
# 918    True
# 920    True
# 921    True
# Name: name, dtype: bool

# %%
df_prod['catalogid'].duplicated().value_counts()
# Out:
# False    1277
# Name: catalogid, dtype: int64

# %%
df_prod.isnull().sum()
# Out:
# catalogid         0
# id                1
# name              1
# image1          115
# thumbnail       117
# price             0
# categories      111
# description     807
# keywords       1085
# stock             0
# dtype: int64

# %%
df_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1277 entries, 0 to 1276
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   catalogid    1277 non-null   int64
#  1   id           1276 non-null   object
#  2   name         1276 non-null   object
#  3   image1       1162 non-null   object
#  4   thumbnail    1160 non-null   object
#  5   price        1277 non-null   float64
#  6   categories   1166 non-null   object
#  7   description  470 non-null    object
#  8   keywords     192 non-null    object
#  9   stock        1277 non-null   float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 99.9+ KB

# %%
df_prod['catalogid'] = df_prod['catalogid'].astype(str)

# %%
df_prod[df_prod['catalogid'] == '3487']['name']
# Out:
# 12    Whelen 500 Series Lens for LED and Halogen with Optics
# Name: name, dtype: object

# %%
df_options = pd.read_csv('options.csv',encoding='unicode_escape')
len(df_options)
# Out:
# 4397

# %%
df_options.columns
# Out:
# Index(['optionid', 'productid', 'catalogid', 'category_id', 'featurecaption',
#        'featuretype', 'featurerequired', 'sorting', 'url', 'info', 'featureid',
#        'featurename', 'featureprice', 'sorting.1', 'partnumber', 'imagepath',
#        'selected', 'hidden', 'optcatalogid', 'qty', 'thumbpath', 'colorcode'],
#       dtype='object')

# %%
df_option_list = df_options.copy()

# %% [markdown]
# 1) identify all unique products(from products dataframe)
# 2) identify all product options(reshape dataframe for merging with the products)
# 3) melt dataframe so there is a product row for every combination of options
# Example:
#
# Product 123 has 2 options with multiple types.
#
# Option 1: Magnetic VS Permanent
# Option 2: Blue VS Green
#
# Product 123 only has 1 skew (123)
#
# I need 4 Skews created
#
#  - 123MBLUE - magnetic and blue
#  - 123PBLUE - permanent and blue
#  - 123MGREEN - magnetic and green
#  - 123PGREEN - permanent and green

# %%
df_option_list.columns
# Out:
# Index(['optionid', 'productid', 'catalogid', 'category_id', 'featurecaption',
#        'featuretype', 'featurerequired', 'sorting', 'url', 'info', 'featureid',
#        'featurename', 'featureprice', 'sorting.1', 'partnumber', 'imagepath',
#        'selected', 'hidden', 'optcatalogid', 'qty', 'thumbpath', 'colorcode'],
#       dtype='object')

# %%
df_option_list.isnull().sum()
# Out:
# optionid           3544
# productid          3544
# catalogid          3544
# category_id        3544
# featurecaption     3544
# featuretype        3544
# featurerequired    3544
# sorting            3544
# url                4396
# info               4395
# featureid             6
# featurename           6
# featureprice          6
# sorting.1             6
# partnumber          554
# imagepath          4397
# selected              6
# hidden                6
# optcatalogid          6
# qty                   6
# thumbpath          4397
# colorcode          2775
# dtype: int64

# %%
df_option_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4397 entries, 0 to 4396
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   optionid         853 non-null    float64
#  1   productid        853 non-null    object
#  2   catalogid        853 non-null    float64
#  3   category_id      853 non-null    float64
#  4   featurecaption   853 non-null    object
#  5   featuretype      853 non-null    object
#  6   featurerequired  853 non-null    float64
#  7   sorting          853 non-null    float64
#  8   url              1 non-null      float64
#  9   info             2 non-null      object
#  10  featureid        4391 non-null   float64
#  11  featurename      4391 non-null   object
#  12  featureprice     4391 non-null   float64
#  13  sorting.1        4391 non-null   float64
#  14  partnumber       3843 non-null   object
#  15  imagepath        0 non-null      float64
#  16  selected         4391 non-null   float64
#  17  hidden           4391 non-null   float64
#  18  optcatalogid     4391 non-null   float64
#  19  qty              4391 non-null   float64
#  20  thumbpath        0 non-null      float64
#  21  colorcode        1622 non-null   object
# dtypes: float64(15), object(7)
# memory usage: 755.9+ KB

# %%
df_option_list.columns
# Out:
# Index(['optionid', 'productid', 'catalogid', 'category_id', 'featurecaption',
#        'featuretype', 'featurerequired', 'sorting', 'url', 'info', 'featureid',
#        'featurename', 'featureprice', 'sorting.1', 'partnumber', 'imagepath',
#        'selected', 'hidden', 'optcatalogid', 'qty', 'thumbpath', 'colorcode'],
#       dtype='object')

# %%
df_option_list = df_option_list[['optionid', 'productid', 'catalogid', 'category_id','featurecaption',
       'featuretype', 'featurerequired', 'sorting', 'url', 'info', 'featureid',
       'featurename','partnumber']]

# %%
df_option_list.head()
# Out:
#    optionid productid  catalogid  category_id                featurecaption  \
# 0    2451.0      RB6T     3457.0          0.0        Choose your Lens Color
# 1       NaN       NaN        NaN          NaN                           NaN
# 2       NaN       NaN        NaN          NaN                           NaN
# 3       NaN       NaN        NaN          NaN                           NaN
# 4    4114.0   11.1002     3474.0          0.0  Choose your Momentary Option
#
#   featuretype  featurerequired  sorting  url info  featureid  \
# 0    Dropdown              1.0      0.0  NaN  NaN    11418.0
# 1         NaN              NaN      NaN  NaN  NaN    11419.0
# 2         NaN              NaN      NaN  NaN  NaN    11420.0
# 3         NaN              NaN      NaN  NaN  NaN    11421.0
# 4    Dropdown              1.0      1.0  NaN  NaN    18984.0
#
#           featurename partnumber
# 0                Blue         BP
# 1               Clear         CP
# 2                 Red         RP
# 3               Amber         AP
# 4  Positive Momentary        .PM

# %%
df_option_list_filled = df_option_list.fillna(method='ffill')

# %%
df_option_list_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4397 entries, 0 to 4396
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   optionid         4397 non-null   float64
#  1   productid        4397 non-null   object
#  2   catalogid        4397 non-null   float64
#  3   category_id      4397 non-null   float64
#  4   featurecaption   4397 non-null   object
#  5   featuretype      4397 non-null   object
#  6   featurerequired  4397 non-null   float64
#  7   sorting          4397 non-null   float64
#  8   url              416 non-null    float64
#  9   info             911 non-null    object
#  10  featureid        4397 non-null   float64
#  11  featurename      4397 non-null   object
#  12  partnumber       4397 non-null   object
# dtypes: float64(7), object(6)
# memory usage: 446.7+ KB

# %% [markdown]
# # Sku format
#
# The SKU will be comprised of the options listed with the partnumbers associated with the options.
#
# Example:
#
# For Product 68, LED(-1183), Non-Optic(725), Amber(-1SB) the sku will read 68-1183725-1SB

# %%
df_option_list_filled[df_option_list_filled['productid'] == '68']
# Out:
#       optionid productid  catalogid  category_id          featurecaption  \
# 27      2462.0        68     3483.0          0.0        Choose your Bulb
# 28      2462.0        68     3483.0          0.0        Choose your Bulb
# 29      2462.0        68     3483.0          0.0        Choose your Bulb
# 30      2463.0        68     3483.0          0.0  Choose your Lens Color
# 31      2463.0        68     3483.0          0.0  Choose your Lens Color
# 32      2463.0        68     3483.0          0.0  Choose your Lens Color
# 33      2463.0        68     3483.0          0.0  Choose your Lens Color
# 30                                                Amber          -1SB
# 31                                                 Blue          -2SB
# 32                                                Clear          -3SB
# 33                                                  Red          -5SB
# 34                                            Non-Optic           725
# 35                                                Optic           726
# 50                                              Halogen          -196
# 51                                                  LED          -196
# 52                                               Strobe       STROBE-
# 53                                                  Red          -50A
# 54                                                Amber          -10A
# 55                                                 Blue          -20A
# 56                                                Clear          -30A
# 57                                      Optic - Halogen      -1963237
# 58                       20? Optic - LED 5MM w/o Flange      -1963583
# 59                           20? Optic - TIR6 Super LED      -1963583
# 60                        20? Optic - LED 5MM w/ Flange      -1963583
# 74                                                Amber          -10A
# 75                                                 Blue          -20A
# 76                                                Clear          -30A
# 77                                                  Red          -50A
# 78                            Non-Optic - Linear Strobe      -3183587
# 79                                      Optic - Halogen      -1183581
# 80                                  Optic - Linear LED       -1183581
# 81                                  Non-Optic - LED 5MM      -3183587
# 82                                      Optic - LED 5MM      -1183581
# 95                                              Halogen      -1183582
# 96                                           Linear LED      -1183582
# 97                                              LED 5MM      -1183582
# 98                                                Amber          -1SA
# 99                                                 Blue          -2SA
# 100                                               Clear          -3SA
# 101                                                 Red          -5SA
# 113                                               Amber          -10A
# 114                                                Blue          -20A
# 115                                               Clear          -30A
# 116                                                 Red          -50A
# 117                             Red - ONLY Strobe KKK-E          E50A
# 118                          Wide Angle Optic - LED 5MM      -1183542
# 119                         Wide Angle Optic - Halogen       -1183542
# 120                          Wide Angle Optic - Strobe       -1183542
# 2860  Smoke Optic Replacement Lens - translucent smoked  -196D335-8SA
# 2861               Clear Replacement Lens - translucent  -196D335-3SA
# 2862      Clear Wide Angle Lense - Has the groves in it  -196D335-3SA
# 3343                  LED - Linear Retro Ballast Driven      -3183573
# 3344                                             Strobe      -3183573
# 3345                                      Amber w/ Seal          -1S0
# 3346                                       Blue w/ Seal          -2S0
# 3347                                      Clear w/ Seal          -3S0
# 3348                                                Red          -5S0

# %%
df_prod[df_prod['id'] == '68'][['id','name','catalogid']]
# Out:
#      id                                                    name catalogid
# 9    68                                  Whelen 400 Series Lens      3483
# 12   68  Whelen 500 Series Lens for LED and Halogen with Optics      3487
# 14   68                                  Whelen 600 Series Lens      3490
# 17   68                            Whelen 700 Series Optic Lens      3493
# 20   68                            Whelen 900 Series Optic Lens      3496
# 704  68                       Whelen ION Clear Replacement Lens      6128
# 819  68                        Whelen 700 Series Non-Optic Lens      6387

# %%
df_prod[df_prod['id'] == '2'][['id','name','catalogid']]
# Out:
#   id                                name catalogid
# 6  2  Whelen Warning Par36 Fairing Light      3479

# %%
df_option_list_filled['partnumber'].value_counts()
# Out:
# #NAME?                  888
# R                       145
# A                       139
# B                       130
# Equipment Info          119
# C                        98
# -R                       72
# BB                       60
# L                        58
# M                        46
# G                        44
# J                        44
# D                        40
# W                        38
# F                        34
# RB                       33
# No SAK                   30
# 2                        29
# E                        29
# V                        27
# P                        24
# 3COLORKIT                24
# K                        24
# -C                       21
# AA                       21
# RC                       20
# 8SP1                     20
# RR                       20
# BC                       19
# MBAJ94                   16
# MKEZ94                   16
# AC                       15
# S4D                       1
# A00MCR                    1
# S4J                       1
# S4F                       1
# S4E                       1
# QM                        1
# AP1                       1
# 2A                        1
# 5017                      1
# BRBR                      1
# CCCC                      1
# BS12                      1
# BS6                       1
# BP6                       1
# BP12                      1
# R00MCR                    1
# C0CDCR                    1
# B00FCR                    1
# R0CDRR                    1
# BCCDCR                    1
# RCCDCR                    1
# DB                        1
# DJ                        1
# REGCS                     1
# BEGCS                     1
# BEHCR                     1
# REHCR                     1
# CT21                      1
# DC11                      1
# DD19                      1
# FX20                      1
# SLC                       1
# SLCHG                     1
# HHS                       1
# LBKT                      1
# Name: partnumber, dtype: int64

# %% [markdown]
# ## Sample skew creation [RB6T and 11.1002]

# %%
df_option_list_filled.iloc[:17]
# Out:
#     optionid productid  catalogid  category_id                featurecaption  \
# 0     2451.0      RB6T     3457.0          0.0        Choose your Lens Color
# 1     2451.0      RB6T     3457.0          0.0        Choose your Lens Color
# 2     2451.0      RB6T     3457.0          0.0        Choose your Lens Color
# 3     2451.0      RB6T     3457.0          0.0        Choose your Lens Color
# 4     4114.0   11.1002     3474.0          0.0  Choose your Momentary Option
# 5     4114.0   11.1002     3474.0          0.0  Choose your Momentary Option
# 6     2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 7     2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 8     2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 9     2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 10    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 11    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 12    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 13    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 14    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 15    2457.0     11.12     3475.0          0.0             Choose your Mount
# 16    2457.0     11.12     3475.0          0.0             Choose your Mount
#
#    featuretype  featurerequired  sorting  url info  featureid  \
# 0     Dropdown              1.0      0.0  NaN  NaN    11418.0
# 1     Dropdown              1.0      0.0  NaN  NaN    11419.0
# 2     Dropdown              1.0      0.0  NaN  NaN    11420.0
# 3     Dropdown              1.0      0.0  NaN  NaN    11421.0
# 4     Dropdown              1.0      1.0  NaN  NaN    18984.0
# 5     Dropdown              1.0      1.0  NaN  NaN    18985.0
# 6     Dropdown              1.0      1.0  NaN  NaN    11444.0
# 7     Dropdown              1.0      1.0  NaN  NaN    11445.0
# 8     Dropdown              1.0      1.0  NaN  NaN    11446.0
# 9     Dropdown              1.0      1.0  NaN  NaN    11447.0
# 10    Dropdown              1.0      1.0  NaN  NaN    11448.0
# 11    Dropdown              1.0      1.0  NaN  NaN    11449.0
# 12    Dropdown              1.0      1.0  NaN  NaN    11450.0
# 13    Dropdown              1.0      1.0  NaN  NaN    11451.0
# 14    Dropdown              1.0      1.0  NaN  NaN    11452.0
# 15    Dropdown              1.0      0.0  NaN  NaN    11443.0
# 16    Dropdown              1.0      0.0  NaN  NaN    24929.0
#
#                   featurename partnumber
# 0                        Blue         BP
# 1                       Clear         CP
# 2                         Red         RP
# 3                       Amber         AP
# 4          Positive Momentary        .PM
# 5   Negative/Ground Momentary       .GSM
# 6                        Blue     #NAME?
# 7                    Red/Blue     #NAME?
# 8                  Blue/White     #NAME?
# 9                   Red/White        -RC
# 10                Amber/White     #NAME?
# 11                      Green     #NAME?
# 12                        Red     #NAME?
# 13                      Amber     #NAME?
# 14                  Red/Amber     #NAME?
# 15                   Magnetic      0.008
# 16                  Permanent          0

# %% [markdown]
# ### Product RB6T

# %%
df_RB6T = df_option_list_filled.iloc[:4]

# %% [markdown]
# ### Create Skew Column

# %%
df_RB6T
# Out:
#    optionid productid  catalogid  category_id          featurecaption  \
# 0    2451.0      RB6T     3457.0          0.0  Choose your Lens Color
# 1    2451.0      RB6T     3457.0          0.0  Choose your Lens Color
# 2    2451.0      RB6T     3457.0          0.0  Choose your Lens Color
# 3    2451.0      RB6T     3457.0          0.0  Choose your Lens Color
#
#   featuretype  featurerequired  sorting  url info  featureid featurename  \
# 0    Dropdown              1.0      0.0  NaN  NaN    11418.0        Blue
# 1    Dropdown              1.0      0.0  NaN  NaN    11419.0       Clear
# 2    Dropdown              1.0      0.0  NaN  NaN    11420.0         Red
# 3    Dropdown              1.0      0.0  NaN  NaN    11421.0       Amber
#
#   partnumber
# 0         BP
# 1         CP
# 2         RP
# 3         AP

# %%
df_RB6T['sku'] = df_RB6T['productid'] + '-' + df_RB6T['partnumber']
df_RB6T
# Out:
# C:\Users\alevi\AppData\Local\Temp\ipykernel_12932\1918591147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RB6T['sku'] = df_RB6T['productid'] + '-' + df_RB6T['partnumber']
#    optionid productid  catalogid  category_id          featurecaption  \
# 0    2451.0      RB6T     3457.0          0.0  Choose your Lens Color
# 1    2451.0      RB6T     3457.0          0.0  Choose your Lens Color
# 2    2451.0      RB6T     3457.0          0.0  Choose your Lens Color
# 3    2451.0      RB6T     3457.0          0.0  Choose your Lens Color
#
#   featuretype  featurerequired  sorting  url info  featureid featurename  \
# 0    Dropdown              1.0      0.0  NaN  NaN    11418.0        Blue
# 1    Dropdown              1.0      0.0  NaN  NaN    11419.0       Clear
# 2    Dropdown              1.0      0.0  NaN  NaN    11420.0         Red
# 3    Dropdown              1.0      0.0  NaN  NaN    11421.0       Amber
#
#   partnumber      sku
# 0         BP  RB6T-BP
# 1         CP  RB6T-CP
# 2         RP  RB6T-RP
# 3         AP  RB6T-AP

# %%
df_11 = df_option_list_filled.iloc[4:17]

# %%
df_11
# Out:
#     optionid productid  catalogid  category_id                featurecaption  \
# 4     4114.0   11.1002     3474.0          0.0  Choose your Momentary Option
# 5     4114.0   11.1002     3474.0          0.0  Choose your Momentary Option
# 6     2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 7     2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 8     2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 9     2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 10    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 11    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 12    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 13    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 14    2458.0     11.12     3475.0          0.0        Choose your LED Colors
# 15    2457.0     11.12     3475.0          0.0             Choose your Mount
# 16    2457.0     11.12     3475.0          0.0             Choose your Mount
#
#    featuretype  featurerequired  sorting  url info  featureid  \
# 4     Dropdown              1.0      1.0  NaN  NaN    18984.0
# 5     Dropdown              1.0      1.0  NaN  NaN    18985.0
# 6     Dropdown              1.0      1.0  NaN  NaN    11444.0
# 7     Dropdown              1.0      1.0  NaN  NaN    11445.0
# 8     Dropdown              1.0      1.0  NaN  NaN    11446.0
# 9     Dropdown              1.0      1.0  NaN  NaN    11447.0
# 10    Dropdown              1.0      1.0  NaN  NaN    11448.0
# 11    Dropdown              1.0      1.0  NaN  NaN    11449.0
# 12    Dropdown              1.0      1.0  NaN  NaN    11450.0
# 13    Dropdown              1.0      1.0  NaN  NaN    11451.0
# 14    Dropdown              1.0      1.0  NaN  NaN    11452.0
# 15    Dropdown              1.0      0.0  NaN  NaN    11443.0
# 16    Dropdown              1.0      0.0  NaN  NaN    24929.0
#
#                   featurename partnumber
# 4          Positive Momentary        .PM
# 5   Negative/Ground Momentary       .GSM
# 6                        Blue     #NAME?
# 7                    Red/Blue     #NAME?
# 8                  Blue/White     #NAME?
# 9                   Red/White        -RC
# 10                Amber/White     #NAME?
# 11                      Green     #NAME?
# 12                        Red     #NAME?
# 13                      Amber     #NAME?
# 14                  Red/Amber     #NAME?
# 15                   Magnetic      0.008
# 16                  Permanent          0

# %%
df_11_moment = df_11.iloc[:2]
df_11_moment_options = list(df_11_moment['featurename'])

# %%
df_11_color = df_11.iloc[2:11]

df_11_color_options = list(df_11_color['featurename'])

# %%
df_11_magperm = df_11.iloc[11:13]
df_11_magperm_options = list(df_11_magperm['featurename'])

# %%
print(df_11_magperm_options)
print(df_11_color_options)
print(df_11_moment_options)
# Out:
# ['Magnetic', 'Permanent']
# ['Blue', 'Red/Blue', 'Blue/White', 'Red/White', 'Amber/White', 'Green', 'Red', 'Amber', 'Red/Amber']
# ['Positive Momentary', 'Negative/Ground Momentary']

# %%
from itertools import product

# Your three lists
options1 = ['Magnetic', 'Permanent']
options2 = ['Blue', 'Red/Blue', 'Blue/White', 'Red/White', 'Amber/White', 'Green', 'Red', 'Amber', 'Red/Amber']
options3 = ['Positive Momentary', 'Negative/Ground Momentary']

# Get every permutation
permutations = list(product(options1, options2, options3))

combos = []
# Print the permutations
for perm in permutations:
    combos.append(perm)

print(len(combos))
combos
# Out:
# 36
# [('Magnetic', 'Blue', 'Positive Momentary'),
#  ('Magnetic', 'Blue', 'Negative/Ground Momentary'),
#  ('Magnetic', 'Red/Blue', 'Positive Momentary'),
#  ('Magnetic', 'Red/Blue', 'Negative/Ground Momentary'),
#  ('Magnetic', 'Blue/White', 'Positive Momentary'),
#  ('Magnetic', 'Blue/White', 'Negative/Ground Momentary'),
#  ('Magnetic', 'Red/White', 'Positive Momentary'),
#  ('Magnetic', 'Red/White', 'Negative/Ground Momentary'),
#  ('Magnetic', 'Amber/White', 'Positive Momentary'),
#  ('Magnetic', 'Amber/White', 'Negative/Ground Momentary'),
#  ('Magnetic', 'Green', 'Positive Momentary'),
#  ('Magnetic', 'Green', 'Negative/Ground Momentary'),
#  ('Magnetic', 'Red', 'Positive Momentary'),
#  ('Magnetic', 'Red', 'Negative/Ground Momentary'),
#  ('Magnetic', 'Amber', 'Positive Momentary'),
#  ('Magnetic', 'Amber', 'Negative/Ground Momentary'),
#  ('Magnetic', 'Red/Amber', 'Positive Momentary'),
#  ('Magnetic', 'Red/Amber', 'Negative/Ground Momentary'),
#  ('Permanent', 'Blue', 'Positive Momentary'),
#  ('Permanent', 'Blue', 'Negative/Ground Momentary'),
#  ('Permanent', 'Red/Blue', 'Positive Momentary'),
#  ('Permanent', 'Red/Blue', 'Negative/Ground Momentary'),
#  ('Permanent', 'Blue/White', 'Positive Momentary'),
#  ('Permanent', 'Blue/White', 'Negative/Ground Momentary'),
#  ('Permanent', 'Red/White', 'Positive Momentary'),
#  ('Permanent', 'Red/White', 'Negative/Ground Momentary'),
#  ('Permanent', 'Amber/White', 'Positive Momentary'),
#  ('Permanent', 'Amber/White', 'Negative/Ground Momentary'),
#  ('Permanent', 'Green', 'Positive Momentary'),
#  ('Permanent', 'Green', 'Negative/Ground Momentary'),
#  ('Permanent', 'Red', 'Positive Momentary'),
#  ('Permanent', 'Red', 'Negative/Ground Momentary'),
#  ('Permanent', 'Amber', 'Positive Momentary'),
#  ('Permanent', 'Amber', 'Negative/Ground Momentary'),
#  ('Permanent', 'Red/Amber', 'Positive Momentary'),
#  ('Permanent', 'Red/Amber', 'Negative/Ground Momentary')]

# %% [markdown]
# ## Functions

# %%
skews = pd.DataFrame(combos,columns = ['Magnetic/Permanent','Color','Positive or Neg/Ground'])



#Created labels for color
skews['Color'] = skews['Color'].apply(lambda x: 'B' if x == 'Blue'\
                                                else 'RB' if x == 'Red/Blue'\
                                                else 'BW' if x =='Blue/White'\
                                                else 'AW' if x == 'Amber/White'\
                                                else 'RW' if x == 'Red/White'\
                                                else  'G' if x =='Green'\
                                                else  'R' if x == 'Red'\
                                                else 'A' if x =='Amber'\
                                                else'RA' if x == 'Red/Amber' else x)
#Created labels for Magnetic vs Permanent
skews['Magnetic/Permanent'] = skews['Magnetic/Permanent'].apply(lambda x: 'M' if x == 'Magnetic'\
                                                                else 'P' if x == 'Permanent' else x)

#Created labels for positive vs negatice/ground momentary
skews['Positive or Neg/Ground'] = skews['Positive or Neg/Ground'].apply(lambda x: 'P' if x == 'Positive Momentary' \
                                                                        else 'NG' if x == 'Negative/Ground Momentary'\
                                                                       else x)
skews['prodid'] = '3474'
skews = skews[['prodid','Magnetic/Permanent', 'Color', 'Positive or Neg/Ground']]
skews['sku'] = skews.sum(axis=1)
skews['description'] = combos
skews
# Out:
#    prodid Magnetic/Permanent Color Positive or Neg/Ground        sku  \
# 0    3474                  M     B                      P    3474MBP
# 1    3474                  M     B                     NG   3474MBNG
# 2    3474                  M    RB                      P   3474MRBP
# 3    3474                  M    RB                     NG  3474MRBNG
# 4    3474                  M    BW                      P   3474MBWP
# 5    3474                  M    BW                     NG  3474MBWNG
# 6    3474                  M    RW                      P   3474MRWP
# 7    3474                  M    RW                     NG  3474MRWNG
# 8    3474                  M    AW                      P   3474MAWP
# 9    3474                  M    AW                     NG  3474MAWNG
# 10   3474                  M     G                      P    3474MGP
# 11   3474                  M     G                     NG   3474MGNG
# 12   3474                  M     R                      P    3474MRP
# 13   3474                  M     R                     NG   3474MRNG
# 14   3474                  M     A                      P    3474MAP
# 15   3474                  M     A                     NG   3474MANG
# 16   3474                  M    RA                      P   3474MRAP
# 17   3474                  M    RA                     NG  3474MRANG
# 18   3474                  P     B                      P    3474PBP
# 19   3474                  P     B                     NG   3474PBNG
# 20   3474                  P    RB                      P   3474PRBP
# 21   3474                  P    RB                     NG  3474PRBNG
# 22   3474                  P    BW                      P   3474PBWP
# 23   3474                  P    BW                     NG  3474PBWNG
# 24   3474                  P    RW                      P   3474PRWP
# 25   3474                  P    RW                     NG  3474PRWNG
# 26   3474                  P    AW                      P   3474PAWP
# 27   3474                  P    AW                     NG  3474PAWNG
# 28   3474                  P     G                      P    3474PGP
# 29   3474                  P     G                     NG   3474PGNG
# 30   3474                  P     R                      P    3474PRP
# 31   3474                  P     R                     NG   3474PRNG
# 32   3474                  P     A                      P    3474PAP
# 33   3474                  P     A                     NG   3474PANG
# 34   3474                  P    RA                      P   3474PRAP
# 35   3474                  P    RA                     NG  3474PRANG
#
#                                             description
# 0                  (Magnetic, Blue, Positive Momentary)
# 1           (Magnetic, Blue, Negative/Ground Momentary)
# 2              (Magnetic, Red/Blue, Positive Momentary)
# 3       (Magnetic, Red/Blue, Negative/Ground Momentary)
# 4            (Magnetic, Blue/White, Positive Momentary)
# 5     (Magnetic, Blue/White, Negative/Ground Momentary)
# 6             (Magnetic, Red/White, Positive Momentary)
# 7      (Magnetic, Red/White, Negative/Ground Momentary)
# 8           (Magnetic, Amber/White, Positive Momentary)
# 9    (Magnetic, Amber/White, Negative/Ground Momentary)
# 10                (Magnetic, Green, Positive Momentary)
# 11         (Magnetic, Green, Negative/Ground Momentary)
# 12                  (Magnetic, Red, Positive Momentary)
# 13           (Magnetic, Red, Negative/Ground Momentary)
# 14                (Magnetic, Amber, Positive Momentary)
# 15         (Magnetic, Amber, Negative/Ground Momentary)
# 16            (Magnetic, Red/Amber, Positive Momentary)
# 17     (Magnetic, Red/Amber, Negative/Ground Momentary)
# 18                (Permanent, Blue, Positive Momentary)
# 19         (Permanent, Blue, Negative/Ground Momentary)
# 20            (Permanent, Red/Blue, Positive Momentary)
# 21     (Permanent, Red/Blue, Negative/Ground Momentary)
# 22          (Permanent, Blue/White, Positive Momentary)
# 23   (Permanent, Blue/White, Negative/Ground Momentary)
# 24           (Permanent, Red/White, Positive Momentary)
# 25    (Permanent, Red/White, Negative/Ground Momentary)
# 26         (Permanent, Amber/White, Positive Momentary)
# 27  (Permanent, Amber/White, Negative/Ground Momentary)
# 28               (Permanent, Green, Positive Momentary)
# 29        (Permanent, Green, Negative/Ground Momentary)
# 30                 (Permanent, Red, Positive Momentary)
# 31          (Permanent, Red, Negative/Ground Momentary)
# 32               (Permanent, Amber, Positive Momentary)
# 33        (Permanent, Amber, Negative/Ground Momentary)
# 34           (Permanent, Red/Amber, Positive Momentary)
# 35    (Permanent, Red/Amber, Negative/Ground Momentary)

# %% [markdown]
# ### More samples - products 2 and 68

# %% [markdown]
# Here we see that the products productid is not enough, but will be fine for the eventual sampling. The catalogid will be the unique product identifier that we will use when we finally merge the csv files.

# %%
df_sample = df_option_list.iloc[17:36]
df_sample = df_sample.fillna(method = 'ffill')

# %%
df_prod[df_prod['id'] == '2'][['id','name']]
# Out:
#   id                                name
# 6  2  Whelen Warning Par36 Fairing Light

# %%
df_prod[df_prod['id'] == '68'][['id','name','catalogid']]
# Out:
#      id                                                    name catalogid
# 9    68                                  Whelen 400 Series Lens      3483
# 12   68  Whelen 500 Series Lens for LED and Halogen with Optics      3487
# 14   68                                  Whelen 600 Series Lens      3490
# 17   68                            Whelen 700 Series Optic Lens      3493
# 20   68                            Whelen 900 Series Optic Lens      3496
# 704  68                       Whelen ION Clear Replacement Lens      6128
# 819  68                        Whelen 700 Series Non-Optic Lens      6387

# %%
df_sample
# Out:
#     optionid productid  catalogid  category_id  \
# 17    2459.0         2     3479.0          0.0
# 18    2459.0         2     3479.0          0.0
# 19    2459.0         2     3479.0          0.0
# 20    2459.0         2     3479.0          0.0
# 21    2459.0         2     3479.0          0.0
# 22    2459.0         2     3479.0          0.0
# 23    2459.0         2     3479.0          0.0
# 24    2459.0         2     3479.0          0.0
# 25    4858.0         2     3479.0          0.0
# 26    4858.0         2     3479.0          0.0
# 27    2462.0        68     3483.0          0.0
# 28    2462.0        68     3483.0          0.0
# 29    2462.0        68     3483.0          0.0
# 30    2463.0        68     3483.0          0.0
# 31    2463.0        68     3483.0          0.0
# 32    2463.0        68     3483.0          0.0
# 33    2463.0        68     3483.0          0.0
# 34    2464.0        68     3483.0          0.0
# 35    2464.0        68     3483.0          0.0
#
#                     featurecaption featuretype  featureid  \
# 17  Choose your LED and Lens Color    Dropdown    11453.0
# 18  Choose your LED and Lens Color    Dropdown    11454.0
# 19  Choose your LED and Lens Color    Dropdown    11455.0
# 20  Choose your LED and Lens Color    Dropdown    11456.0
# 21  Choose your LED and Lens Color    Dropdown    18738.0
# 22  Choose your LED and Lens Color    Dropdown    18739.0
# 23  Choose your LED and Lens Color    Dropdown    18740.0
# 24  Choose your LED and Lens Color    Dropdown    18741.0
# 25          Choose your Lens Style    Dropdown    24256.0
# 26          Choose your Lens Style    Dropdown    24257.0
# 27                Choose your Bulb    Dropdown    11466.0
# 28                Choose your Bulb    Dropdown    11467.0
# 29                Choose your Bulb    Dropdown    11468.0
# 30          Choose your Lens Color    Dropdown    11469.0
# 31          Choose your Lens Color    Dropdown    11470.0
# 32          Choose your Lens Color    Dropdown    11471.0
# 33          Choose your Lens Color    Dropdown    11472.0
# 34               Choose your Model    Dropdown    11473.0
# 35               Choose your Model    Dropdown    11474.0
#
#                                     featurename partnumber
# 17                         Blue with Clear Lens     B00ZCR
# 18                        White with Clear Lens     C00ZCR
# 19                          Red with Clear Lens     R00ZCR
# 20                        Amber with Clear Lens     A00ZCR
# 21  Red/Blue with Clear Lens EXTENDED LENS ONLY     J00ZCR
# 22                        Amber with Amber Lens     A00ZAR
# 23                          Blue with Blue Lens     B00ZBR
# 24                            Red with Red Lens     R00ZRR
# 25                                Extended Lens          E
# 26                                    Flat Lens          F
# 27                                          LED      -1183
# 28                                       Strobe      -3183
# 29                                      Halogen      -1183
# 30                                        Amber       -1SB
# 31                                         Blue       -2SB
# 32                                        Clear       -3SB
# 33                                          Red       -5SB
# 34                                    Non-Optic        725
# 35                                        Optic        726

# %%
df_prod.head()
# Out:
#   catalogid         id                                           name  \
# 0      3457       RB6T         Whelen Dual Reflector Rota-Beam Beacon
# 1      3465  11.1005SF      Sho-Me Universal Strobe-Style LED Flasher
# 2      3466    11.1032  Sho-Me Micro Switch with Built-In LED Flasher
# 3      3474    11.1002           Sho-Me Universal On/Off/Flash Switch
# 4      3475     11.120           Sho-Me Low-Profile LED Mini Lightbar
#
#                                                                          image1  \
# 0                       assets/images/whelen-RB6-dual-rotabeam-beacon-amber.jpg
# 1                 assets/images/able-2-sho-me-strobe-style-flasher-111005SF.jpg
# 2                                 assets/images/able-2-sho-me-switch-111032.jpg
# 3                 assets/images/able2-sho-me-on-off-mometary-switch-11-1002.jpg
# 4  assets/images/able2-sho-me-on-low-profile-mini-lightbar-11-1200-red-blue.jpg
#
#                                                                                            thumbnail  \
# 0                       assets/images/thumbnails/whelen-rb6-dual-rotabeam-beacon-amber_thumbnail.jpg
# 1                 assets/images/thumbnails/able-2-sho-me-strobe-style-flasher-111005sf_thumbnail.jpg
# 2                                 assets/images/thumbnails/able-2-sho-me-switch-111032_thumbnail.jpg
# 3                 assets/images/thumbnails/able2-sho-me-on-off-mometary-switch-11-1002_thumbnail.jpg
# 4  assets/images/thumbnails/able2-sho-me-on-low-profile-mini-lightbar-11-1200-red-blue_thumbnail.jpg
#
#     price                 categories  \
# 0  227.99  360° Beacons/360° Beacons
# 1   26.99            Flasher Modules
# 2   52.99     Switches & Controllers
# 3   28.99     Switches & Controllers
# 4  349.99   Lightbars/Mini Lightbars
#
#                                                                                            description  \
# 0  The RB6T is a versatile, mid-sized beacon, perfect for utility, maintenance, fire and rescue app...
# 1  This Able 2/Sho-Me Universal Strobe-Style LED Flasher features flash patterns in your choice of ...
# 2  This touch pad switch features a built in LED flasher and is the smallest switch of its kind on ...
# 3  This Sho-Me universal on/off switch features a momentary switch which will work with most any po...
# 4  The Able 2 Low-Profile LED Mini Lightbar offers 360 degree light output with a continuous loop o...
#
#                                                keywords    stock
# 0                                                   NaN  99995.0
# 1                       Able 2, Universal, LED, Flasher  99971.0
# 2  Able 2, sho me, Micro Switch, Built in, LED, Flasher  99999.0
# 3   Able 2, show me, shome,  On, Off, Momentary, Switch  99992.0
# 4              Able 2, Low-Profile, LED, Mini, Lightbar  99998.0

# %%
df_prod[df_prod['id'] == '2'][['id','name']]
# Out:
#   id                                name
# 6  2  Whelen Warning Par36 Fairing Light

# %%
df_sample[df_sample['optionid'] == 2459.0]
# Out:
#     optionid productid  catalogid  category_id  \
# 17    2459.0         2     3479.0          0.0
# 18    2459.0         2     3479.0          0.0
# 19    2459.0         2     3479.0          0.0
# 20    2459.0         2     3479.0          0.0
# 21    2459.0         2     3479.0          0.0
# 22    2459.0         2     3479.0          0.0
# 23    2459.0         2     3479.0          0.0
# 24    2459.0         2     3479.0          0.0
#
#                     featurecaption featuretype  featureid  \
# 17  Choose your LED and Lens Color    Dropdown    11453.0
# 18  Choose your LED and Lens Color    Dropdown    11454.0
# 19  Choose your LED and Lens Color    Dropdown    11455.0
# 20  Choose your LED and Lens Color    Dropdown    11456.0
# 21  Choose your LED and Lens Color    Dropdown    18738.0
# 22  Choose your LED and Lens Color    Dropdown    18739.0
# 23  Choose your LED and Lens Color    Dropdown    18740.0
# 24  Choose your LED and Lens Color    Dropdown    18741.0
#
#                                     featurename partnumber
# 17                         Blue with Clear Lens     B00ZCR
# 18                        White with Clear Lens     C00ZCR
# 19                          Red with Clear Lens     R00ZCR
# 20                        Amber with Clear Lens     A00ZCR
# 21  Red/Blue with Clear Lens EXTENDED LENS ONLY     J00ZCR
# 22                        Amber with Amber Lens     A00ZAR
# 23                          Blue with Blue Lens     B00ZBR
# 24                            Red with Red Lens     R00ZRR

# %%
df_sample[df_sample['optionid'] == 4858.0]
# Out:
#     optionid productid  catalogid  category_id          featurecaption  \
# 25    4858.0         2     3479.0          0.0  Choose your Lens Style
# 26    4858.0         2     3479.0          0.0  Choose your Lens Style
#
#    featuretype  featureid    featurename partnumber
# 25    Dropdown    24256.0  Extended Lens          E
# 26    Dropdown    24257.0      Flat Lens          F

# %%
from itertools import product

# Your three lists
options1 = list(df_sample[df_sample['optionid'] == 2459.0]['featurename'])
options2 = list(df_sample[df_sample['optionid'] == 4858.0]['featurename'])
# Get every permutation
permutations = list(product(options1, options2))

combos = []
# Print the permutations
for perm in permutations:
    combos.append(perm)

print(len(combos))
combos
# Out:
# 16
# [('Blue with Clear Lens', 'Extended Lens'),
#  ('Blue with Clear Lens', 'Flat Lens'),
#  ('White with Clear Lens', 'Extended Lens'),
#  ('White with Clear Lens', 'Flat Lens'),
#  ('Red with Clear Lens', 'Extended Lens'),
#  ('Red with Clear Lens', 'Flat Lens'),
#  ('Amber with Clear Lens', 'Extended Lens'),
#  ('Amber with Clear Lens', 'Flat Lens'),
#  ('Red/Blue with Clear Lens EXTENDED LENS ONLY', 'Extended Lens'),
#  ('Red/Blue with Clear Lens EXTENDED LENS ONLY', 'Flat Lens'),
#  ('Amber with Amber Lens', 'Extended Lens'),
#  ('Amber with Amber Lens', 'Flat Lens'),
#  ('Blue with Blue Lens', 'Extended Lens'),
#  ('Blue with Blue Lens', 'Flat Lens'),
#  ('Red with Red Lens', 'Extended Lens'),
#  ('Red with Red Lens', 'Flat Lens')]

# %% [markdown]
# ## Functions

# %%
def replace_words_with_first_letter(text):
    words = text.split()
    initials = [word[0].upper() for word in words]
    return ''.join(initials)

# skew_sample['color_lens'] = skew_sample['color_lens'].apply(replace_words_with_first_letter)

# %%
skew_sample = pd.DataFrame(combos,columns = ['color_lens', 'Ext_or_Fl'])

skew_sample['color_lens'] = skew_sample['color_lens'].apply(replace_words_with_first_letter)
skew_sample['Ext_or_Fl'] = skew_sample['Ext_or_Fl'].apply(replace_words_with_first_letter)
skew_sample['prodid'] = '3479'
skew_sample = skew_sample[['prodid','color_lens','Ext_or_Fl']]
skew_sample['sku'] = skew_sample.sum(axis=1)
skew_sample['description'] = combos
skew_sample
# Out:
#    prodid color_lens Ext_or_Fl            sku  \
# 0    3479       BWCL        EL     3479BWCLEL
# 1    3479       BWCL        FL     3479BWCLFL
# 2    3479       WWCL        EL     3479WWCLEL
# 3    3479       WWCL        FL     3479WWCLFL
# 4    3479       RWCL        EL     3479RWCLEL
# 5    3479       RWCL        FL     3479RWCLFL
# 6    3479       AWCL        EL     3479AWCLEL
# 7    3479       AWCL        FL     3479AWCLFL
# 8    3479    RWCLELO        EL  3479RWCLELOEL
# 9    3479    RWCLELO        FL  3479RWCLELOFL
# 10   3479       AWAL        EL     3479AWALEL
# 11   3479       AWAL        FL     3479AWALFL
# 12   3479       BWBL        EL     3479BWBLEL
# 13   3479       BWBL        FL     3479BWBLFL
# 14   3479       RWRL        EL     3479RWRLEL
# 15   3479       RWRL        FL     3479RWRLFL
#
#                                                      description
# 0                          (Blue with Clear Lens, Extended Lens)
# 1                              (Blue with Clear Lens, Flat Lens)
# 2                         (White with Clear Lens, Extended Lens)
# 3                             (White with Clear Lens, Flat Lens)
# 4                           (Red with Clear Lens, Extended Lens)
# 5                               (Red with Clear Lens, Flat Lens)
# 6                         (Amber with Clear Lens, Extended Lens)
# 7                             (Amber with Clear Lens, Flat Lens)
# 8   (Red/Blue with Clear Lens EXTENDED LENS ONLY, Extended Lens)
# 9       (Red/Blue with Clear Lens EXTENDED LENS ONLY, Flat Lens)
# 10                        (Amber with Amber Lens, Extended Lens)
# 11                            (Amber with Amber Lens, Flat Lens)
# 12                          (Blue with Blue Lens, Extended Lens)
# 13                              (Blue with Blue Lens, Flat Lens)
# 14                            (Red with Red Lens, Extended Lens)
# 15                                (Red with Red Lens, Flat Lens)

# %%
list(skew_sample['sku'])
# Out:
# ['3479BWCLEL',
#  '3479BWCLFL',
#  '3479WWCLEL',
#  '3479WWCLFL',
#  '3479RWCLEL',
#  '3479RWCLFL',
#  '3479AWCLEL',
#  '3479AWCLFL',
#  '3479RWCLELOEL',
#  '3479RWCLELOFL',
#  '3479AWALEL',
#  '3479AWALFL',
#  '3479BWBLEL',
#  '3479BWBLFL',
#  '3479RWRLEL',
#  '3479RWRLFL']

# %%
df_sample[df_sample['optionid'] == 2462.0]
df_sample[df_sample['optionid'] == 2463.0]
df_sample[df_sample['optionid'] == 2464.0]
# Out:
#     optionid productid  catalogid  category_id     featurecaption featuretype  \
# 34    2464.0        68     3483.0          0.0  Choose your Model    Dropdown
# 35    2464.0        68     3483.0          0.0  Choose your Model    Dropdown
#
#     featureid featurename partnumber
# 34    11473.0   Non-Optic        725
# 35    11474.0       Optic        726

# %%
from itertools import product

# Your three lists
options1 = list(df_sample[df_sample['optionid'] == 2462.0]['featurename'])
options2 = list(df_sample[df_sample['optionid'] == 2463.0]['featurename'])
options3 = list(df_sample[df_sample['optionid'] == 2464.0]['featurename'])
# Get every permutation
permutations = list(product(options1, options2,options3))

combos = []
# Print the permutations
for perm in permutations:
    combos.append(perm)

print(len(combos))
combos
# Out:
# 24
# [('LED', 'Amber', 'Non-Optic'),
#  ('LED', 'Amber', 'Optic'),
#  ('LED', 'Blue', 'Non-Optic'),
#  ('LED', 'Blue', 'Optic'),
#  ('LED', 'Clear', 'Non-Optic'),
#  ('LED', 'Clear', 'Optic'),
#  ('LED', 'Red', 'Non-Optic'),
#  ('LED', 'Red', 'Optic'),
#  ('Strobe', 'Amber', 'Non-Optic'),
#  ('Strobe', 'Amber', 'Optic'),
#  ('Strobe', 'Blue', 'Non-Optic'),
#  ('Strobe', 'Blue', 'Optic'),
#  ('Strobe', 'Clear', 'Non-Optic'),
#  ('Strobe', 'Clear', 'Optic'),
#  ('Strobe', 'Red', 'Non-Optic'),
#  ('Strobe', 'Red', 'Optic'),
#  ('Halogen', 'Amber', 'Non-Optic'),
#  ('Halogen', 'Amber', 'Optic'),
#  ('Halogen', 'Blue', 'Non-Optic'),
#  ('Halogen', 'Blue', 'Optic'),
#  ('Halogen', 'Clear', 'Non-Optic'),
#  ('Halogen', 'Clear', 'Optic'),
#  ('Halogen', 'Red', 'Non-Optic'),
#  ('Halogen', 'Red', 'Optic')]

# %%
skew_sample_2 = pd.DataFrame(combos,columns = ['light', 'color','optic'])

skew_sample_2['optic'] = skew_sample_2['optic'].str.replace('-', ' ')
skew_sample_2 = skew_sample_2.applymap(replace_words_with_first_letter)
skew_sample_2['prodid'] = '3483'
skew_sample_2 = skew_sample_2[['prodid','light', 'color','optic']]
skew_sample_2['sku'] = skew_sample_2.sum(axis=1)
skew_sample_2['description'] = combos
skew_sample_2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:969, in _finalize_columns_and_data(content, columns, dtype)
#     968 try:
# --> 969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:1017, in _validate_or_indexify_columns(content, columns)
#    1015 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1016     # caller's responsibility to check for this...
# -> 1017     raise AssertionError(
#    1018         f"{len(columns)} columns passed, passed data had "
#    1019         f"{len(content)} columns"
#    1020     )
#    1021 elif is_mi_list:
#    1022
#    1023     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 3 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 skew_sample_2 = pd.DataFrame(combos,columns = ['light', 'color','optic'])
#       3 skew_sample_2['optic'] = skew_sample_2['optic'].str.replace('-', ' ')
#       4 skew_sample_2 = skew_sample_2.applymap(replace_words_with_first_letter)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:746, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     744     if columns is not None:
#     745         columns = ensure_index(columns)
# --> 746     arrays, columns, index = nested_data_to_arrays(
#     747         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     748         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     749         data,
#     750         columns,
#     751         index,  # type: ignore[arg-type]
#     752         dtype,
#     753     )
#     754     mgr = arrays_to_mgr(
#     755         arrays,
#     756         columns,
#    (...)
#     759         typ=manager,
#     760     )
#     761 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:510, in nested_data_to_arrays(data, columns, index, dtype)
#     507 if is_named_tuple(data[0]) and columns is None:
#     508     columns = ensure_index(data[0]._fields)
# --> 510 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     511 columns = ensure_index(columns)
#     513 if index is None:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:875, in to_arrays(data, columns, dtype)
#     872     data = [tuple(x) for x in data]
#     873     arr = _list_to_arrays(data)
# --> 875 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     876 return content, columns
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:972, in _finalize_columns_and_data(content, columns, dtype)
#     969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
# --> 972     raise ValueError(err) from err
#     974 if len(contents) and contents[0].dtype == np.object_:
#     975     contents = _convert_object_array(contents, dtype=dtype)
#
# ValueError: 3 columns passed, passed data had 2 columns

# %%
df_3487 = df_option_list.iloc[50:61]
df_3487
# Out:
#     optionid productid  catalogid  category_id          featurecaption  \
# 50    2467.0        68     3487.0          0.0        Choose your Bulb
# 51       NaN       NaN        NaN          NaN                     NaN
# 52       NaN       NaN        NaN          NaN                     NaN
# 53    2468.0        68     3487.0          0.0  Choose your Lens Color
# 54       NaN       NaN        NaN          NaN                     NaN
# 55       NaN       NaN        NaN          NaN                     NaN
# 56       NaN       NaN        NaN          NaN                     NaN
# 57    2469.0        68     3487.0          0.0       Choose your Model
# 58       NaN       NaN        NaN          NaN                     NaN
# 59       NaN       NaN        NaN          NaN                     NaN
# 60       NaN       NaN        NaN          NaN                     NaN
#
#    featuretype  featureid                     featurename partnumber
# 50    Dropdown    11487.0                         Halogen       -196
# 51         NaN    11488.0                             LED       -196
# 52         NaN    11489.0                          Strobe    STROBE-
# 53    Dropdown    11490.0                             Red       -50A
# 54         NaN    11491.0                           Amber       -10A
# 55         NaN    11492.0                            Blue       -20A
# 56         NaN    11493.0                           Clear       -30A
# 57    Dropdown    11494.0                 Optic - Halogen   -1963237
# 58         NaN    11495.0  20? Optic - LED 5MM w/o Flange   -1963583
# 59         NaN    29439.0      20? Optic - TIR6 Super LED   -1963583
# 60         NaN    29478.0   20? Optic - LED 5MM w/ Flange   -1963583

# %%
df_3487 = df_option_list.iloc[50:61]
df_3487 = df_3487.fillna(method = 'ffill')
df_2467 = df_3487[df_3487['optionid'] == 2467.0]
df_2468 = df_3487[df_3487['optionid'] == 2468.0]
df_2469 = df_3487[df_3487['optionid'] == 2469.0]


from itertools import product

# Your three lists
options1 = list(df_3487[df_3487['optionid'] == 2467.0]['featurename'])
options2 = list(df_3487[df_3487['optionid'] == 2468.0]['featurename'])
options3 = list(df_3487[df_3487['optionid'] == 2469.0]['featurename'])
# Get every permutation
permutations = list(product(options1, options2,options3))

combos = []
# Print the permutations
for perm in permutations:
    combos.append(perm)

print(len(combos))
combos


skew_sample_3487 = pd.DataFrame(combos,columns = ['bulb', 'color_lens','model'])

skew_sample_3487['model'] = skew_sample_3487['model'].str.replace('-', ' ').str.replace('?', '').str.replace('w/', 'w')
skew_sample_3487 = skew_sample_3487.applymap(replace_words_with_first_letter)
skew_sample_3487['prodid'] = '3487'
skew_sample_3487 = skew_sample_3487[['prodid','bulb', 'color_lens','model']]
skew_sample_3487['sku'] = skew_sample_3487.sum(axis=1)
skew_sample_3487['description'] = combos
skew_sample_3487
# Out:
# 48
# C:\Users\alevi\AppData\Local\Temp\ipykernel_20248\2034858653.py:28: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   skew_sample_3487['model'] = skew_sample_3487['model'].str.replace('-', ' ').str.replace('?', '').str.replace('w/', 'w')
#    prodid bulb color_lens   model           sku  \
# 0    3487    H          R      OH      3487HROH
# 1    3487    H          R  2OL5WF  3487HR2OL5WF
# 2    3487    H          R   2OTSL   3487HR2OTSL
# 3    3487    H          R  2OL5WF  3487HR2OL5WF
# 4    3487    H          A      OH      3487HAOH
# 5    3487    H          A  2OL5WF  3487HA2OL5WF
# 6    3487    H          A   2OTSL   3487HA2OTSL
# 7    3487    H          A  2OL5WF  3487HA2OL5WF
# 8    3487    H          B      OH      3487HBOH
# 9    3487    H          B  2OL5WF  3487HB2OL5WF
# 10   3487    H          B   2OTSL   3487HB2OTSL
# 11   3487    H          B  2OL5WF  3487HB2OL5WF
# 12   3487    H          C      OH      3487HCOH
# 13   3487    H          C  2OL5WF  3487HC2OL5WF
# 14   3487    H          C   2OTSL   3487HC2OTSL
# 15   3487    H          C  2OL5WF  3487HC2OL5WF
# 16   3487    L          R      OH      3487LROH
# 17   3487    L          R  2OL5WF  3487LR2OL5WF
# 18   3487    L          R   2OTSL   3487LR2OTSL
# 19   3487    L          R  2OL5WF  3487LR2OL5WF
# 20   3487    L          A      OH      3487LAOH
# 21   3487    L          A  2OL5WF  3487LA2OL5WF
# 22   3487    L          A   2OTSL   3487LA2OTSL
# 23   3487    L          A  2OL5WF  3487LA2OL5WF
# 24   3487    L          B      OH      3487LBOH
# 25   3487    L          B  2OL5WF  3487LB2OL5WF
# 26   3487    L          B   2OTSL   3487LB2OTSL
# 27   3487    L          B  2OL5WF  3487LB2OL5WF
# 28   3487    L          C      OH      3487LCOH
# 29   3487    L          C  2OL5WF  3487LC2OL5WF
# 30   3487    L          C   2OTSL   3487LC2OTSL
# 31   3487    L          C  2OL5WF  3487LC2OL5WF
# 32   3487    S          R      OH      3487SROH
# 33   3487    S          R  2OL5WF  3487SR2OL5WF
# 34   3487    S          R   2OTSL   3487SR2OTSL
# 35   3487    S          R  2OL5WF  3487SR2OL5WF
# 36   3487    S          A      OH      3487SAOH
# 37   3487    S          A  2OL5WF  3487SA2OL5WF
# 38   3487    S          A   2OTSL   3487SA2OTSL
# 39   3487    S          A  2OL5WF  3487SA2OL5WF
# 40   3487    S          B      OH      3487SBOH
# 41   3487    S          B  2OL5WF  3487SB2OL5WF
# 42   3487    S          B   2OTSL   3487SB2OTSL
# 43   3487    S          B  2OL5WF  3487SB2OL5WF
# 44   3487    S          C      OH      3487SCOH
# 45   3487    S          C  2OL5WF  3487SC2OL5WF
# 46   3487    S          C   2OTSL   3487SC2OTSL
# 47   3487    S          C  2OL5WF  3487SC2OL5WF
#
#                                          description
# 0                    (Halogen, Red, Optic - Halogen)
# 1     (Halogen, Red, 20? Optic - LED 5MM w/o Flange)
# 2         (Halogen, Red, 20? Optic - TIR6 Super LED)
# 3      (Halogen, Red, 20? Optic - LED 5MM w/ Flange)
# 4                  (Halogen, Amber, Optic - Halogen)
# 5   (Halogen, Amber, 20? Optic - LED 5MM w/o Flange)
# 6       (Halogen, Amber, 20? Optic - TIR6 Super LED)
# 7    (Halogen, Amber, 20? Optic - LED 5MM w/ Flange)
# 8                   (Halogen, Blue, Optic - Halogen)
# 9    (Halogen, Blue, 20? Optic - LED 5MM w/o Flange)
# 10       (Halogen, Blue, 20? Optic - TIR6 Super LED)
# 11    (Halogen, Blue, 20? Optic - LED 5MM w/ Flange)
# 12                 (Halogen, Clear, Optic - Halogen)
# 13  (Halogen, Clear, 20? Optic - LED 5MM w/o Flange)
# 14      (Halogen, Clear, 20? Optic - TIR6 Super LED)
# 15   (Halogen, Clear, 20? Optic - LED 5MM w/ Flange)
# 16                       (LED, Red, Optic - Halogen)
# 17        (LED, Red, 20? Optic - LED 5MM w/o Flange)
# 18            (LED, Red, 20? Optic - TIR6 Super LED)
# 19         (LED, Red, 20? Optic - LED 5MM w/ Flange)
# 20                     (LED, Amber, Optic - Halogen)
# 21      (LED, Amber, 20? Optic - LED 5MM w/o Flange)
# 22          (LED, Amber, 20? Optic - TIR6 Super LED)
# 23       (LED, Amber, 20? Optic - LED 5MM w/ Flange)
# 24                      (LED, Blue, Optic - Halogen)
# 25       (LED, Blue, 20? Optic - LED 5MM w/o Flange)
# 26           (LED, Blue, 20? Optic - TIR6 Super LED)
# 27        (LED, Blue, 20? Optic - LED 5MM w/ Flange)
# 28                     (LED, Clear, Optic - Halogen)
# 29      (LED, Clear, 20? Optic - LED 5MM w/o Flange)
# 30          (LED, Clear, 20? Optic - TIR6 Super LED)
# 31       (LED, Clear, 20? Optic - LED 5MM w/ Flange)
# 32                    (Strobe, Red, Optic - Halogen)
# 33     (Strobe, Red, 20? Optic - LED 5MM w/o Flange)
# 34         (Strobe, Red, 20? Optic - TIR6 Super LED)
# 35      (Strobe, Red, 20? Optic - LED 5MM w/ Flange)
# 36                  (Strobe, Amber, Optic - Halogen)
# 37   (Strobe, Amber, 20? Optic - LED 5MM w/o Flange)
# 38       (Strobe, Amber, 20? Optic - TIR6 Super LED)
# 39    (Strobe, Amber, 20? Optic - LED 5MM w/ Flange)
# 40                   (Strobe, Blue, Optic - Halogen)
# 41    (Strobe, Blue, 20? Optic - LED 5MM w/o Flange)
# 42        (Strobe, Blue, 20? Optic - TIR6 Super LED)
# 43     (Strobe, Blue, 20? Optic - LED 5MM w/ Flange)
# 44                  (Strobe, Clear, Optic - Halogen)
# 45   (Strobe, Clear, 20? Optic - LED 5MM w/o Flange)
# 46       (Strobe, Clear, 20? Optic - TIR6 Super LED)
# 47    (Strobe, Clear, 20? Optic - LED 5MM w/ Flange)

# %%
skew_6 = skew_sample_2[['prodid','sku','description']]
skew_2 = skew_sample[['prodid','sku','description']]
skew_11 = skews[['prodid','sku','description']]
skew_3487 = skew_sample_3487[['prodid','sku','description']]
skew_rb = df_RB6T[['sku','description']]
skew_rb['prodid'] = '3457'
skew_sample_list = pd.concat([skew_6,skew_2,skew_11,skew_rb, skew_3487])
skew_sample_list.columns = ['prodid','sku','option_description']
def join_tuple_with_underscore(t):
    return '_'.join(map(str, t))

skew_sample_list['option_description'] = skew_sample_list['option_description'].apply(join_tuple_with_underscore)
skew_sample_list
# Out:
# C:\Users\alevi\AppData\Local\Temp\ipykernel_20248\2395428108.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   
# 13   3487   3487HC2OL5WF       Halogen_Clear_20? Optic - LED 5MM w/o Flange
# 14   3487    3487HC2OTSL           Halogen_Clear_20? Optic - TIR6 Super LED
# 15   3487   3487HC2OL5WF        Halogen_Clear_20? Optic - LED 5MM w/ Flange
# 16   3487       3487LROH                            LED_Red_Optic - Halogen
# 17   3487   3487LR2OL5WF             LED_Red_20? Optic - LED 5MM w/o Flange
# 18   3487    3487LR2OTSL                 LED_Red_20? Optic - TIR6 Super LED
# 19   3487   3487LR2OL5WF              LED_Red_20? Optic - LED 5MM w/ Flange
# 20   3487       3487LAOH                          LED_Amber_Optic - Halogen
# 21   3487   3487LA2OL5WF           LED_Amber_20? Optic - LED 5MM w/o Flange
# 22   3487    3487LA2OTSL               LED_Amber_20? Optic - TIR6 Super LED
# 23   3487   3487LA2OL5WF            LED_Amber_20? Optic - LED 5MM w/ Flange
# 24   3487       3487LBOH                           LED_Blue_Optic - Halogen
# 25   3487   3487LB2OL5WF            LED_Blue_20? Optic - LED 5MM w/o Flange
# 26   3487    3487LB2OTSL                LED_Blue_20? Optic - TIR6 Super LED
# 27   3487   3487LB2OL5WF             LED_Blue_20? Optic - LED 5MM w/ Flange
# 28   3487       3487LCOH                          LED_Clear_Optic - Halogen
# 29   3487   3487LC2OL5WF           LED_Clear_20? Optic - LED 5MM w/o Flange
# 30   3487    3487LC2OTSL               LED_Clear_20? Optic - TIR6 Super LED
# 31   3487   3487LC2OL5WF            LED_Clear_20? Optic - LED 5MM w/ Flange
# 32   3487       3487SROH                         Strobe_Red_Optic - Halogen
# 33   3487   3487SR2OL5WF          Strobe_Red_20? Optic - LED 5MM w/o Flange
# 34   3487    3487SR2OTSL              Strobe_Red_20? Optic - TIR6 Super LED
# 35   3487   3487SR2OL5WF           Strobe_Red_20? Optic - LED 5MM w/ Flange
# 36   3487       3487SAOH                       Strobe_Amber_Optic - Halogen
# 37   3487   3487SA2OL5WF        Strobe_Amber_20? Optic - LED 5MM w/o Flange
# 38   3487    3487SA2OTSL            Strobe_Amber_20? Optic - TIR6 Super LED
# 39   3487   3487SA2OL5WF         Strobe_Amber_20? Optic - LED 5MM w/ Flange
# 40   3487       3487SBOH                        Strobe_Blue_Optic - Halogen
# 41   3487   3487SB2OL5WF         Strobe_Blue_20? Optic - LED 5MM w/o Flange
# 42   3487    3487SB2OTSL             Strobe_Blue_20? Optic - TIR6 Super LED
# 43   3487   3487SB2OL5WF          Strobe_Blue_20? Optic - LED 5MM w/ Flange
# 44   3487       3487SCOH                       Strobe_Clear_Optic - Halogen
# 45   3487   3487SC2OL5WF        Strobe_Clear_20? Optic - LED 5MM w/o Flange
# 46   3487    3487SC2OTSL            Strobe_Clear_20? Optic - TIR6 Super LED
# 47   3487   3487SC2OL5WF         Strobe_Clear_20? Optic - LED 5MM w/ Flange

# %%
df_prod['catalogid'] = df_prod['catalogid'].astype(str)

# %%
product_option_list_sample = skew_sample_list.merge(df_prod, how='inner', left_on='prodid',right_on='catalogid')

# %%
product_option_list_sample.to_csv('product_option_list_sample.csv')
