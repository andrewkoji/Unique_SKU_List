# %% [markdown]
# # Shift 4 Shop - API Scrape of all products
#
# In the code below, the Strobes N More website API calls were performed to gain access to the API for all products on the website.

# %% [markdown]
# # Pandas
#
# The pandas library is imported here for dataframe manipulation

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", 100)

# %% [markdown]
# # API call - First 200 products
#
# This Python code snippet appears to be making an HTTP request to an API endpoint using the urllib.request module to fetch product data from an e-commerce platform 3dcart.
#
#
# This code sends an HTTP GET request to the specified API endpoint ('https://apirest.3dcart.com/3dCartWebAPI/v2/Products?limit=200') with headers containing authentication credentials. It then reads the response, decodes it from bytes to a UTF-8 encoded string, and parses the JSON data into Python objects (a list of dictionaries representing product information). It then appends this list of products to the product_lists list.

# %%
# Import necessary modules
from urllib.request import Request, urlopen
import json

# Initialize an empty list to store product lists
product_lists = []

# Define headers required for the API request
headers = {
    'Content-Type': 'application/json',
    'Accept': 'application/json',
    'SecureURL': 'https://www.strobesnmore.com',  # Assuming this is the URL of the API endpoint
    'PrivateKey': 'mykey',  # Private key for authentication
    'Token': 'mytoken'  # Token for authentication
}

# Construct the request object with the specified URL and headers
request = Request('https://apirest.3dcart.com/3dCartWebAPI/v2/Products?limit=200', headers=headers)

# Open the URL and read the response
body_1 = urlopen(request).read()

# Decode the response bytes to a string using UTF-8 encoding
response_str = body_1.decode('utf-8')

# Load the JSON string into a Python list of dictionaries
product_list = json.loads(response_str)

# Append the retrieved product list to the main product_lists list
product_lists.append(product_list)

# %%
len(product_lists[0])
# Out:
# 200

# %% [markdown]
# This code iterates over the list of numbers, each representing an offset for paginated API requests. For each number, it constructs a URL with the appropriate offset, sends an HTTP GET request with the specified headers, reads the response, decodes it from bytes to a UTF-8 encoded string, parses the JSON data into Python objects (presumably a list of dictionaries representing product information), prints the length of the retrieved product list, and finally appends it to the product_lists list.

# %%
# Import necessary modules
from urllib.request import Request, urlopen
import json

# Initialize a list of numbers to be used as offsets for paginated API requests
numbered_list = [200, 400, 600, 800, 1000, 1200]

# Define headers required for the API request
headers = {
    'Content-Type': 'application/json',
    'Accept': 'application/json',
    'SecureURL': 'https://www.strobesnmore.com',  # Assuming this is the URL of the API endpoint
    'PrivateKey': 'mykey',  # Private key for authentication
    'Token': 'mytoken'  # Token for authentication
}

# Iterate over the list of numbers
for number in numbered_list:
    # Construct the request URL with the specified offset
    request = Request(f'https://apirest.3dcart.com/3dCartWebAPI/v2/Products?limit=200&offset={number}', headers=headers)
    
    # Open the URL and read the response
    response_body = urlopen(request).read()
    
    # Decode the response body from bytes to a string using UTF-8 encoding
    response_str = response_body.decode('utf-8')
    
    # Load the JSON string into a Python list of dictionaries
    product_list = json.loads(response_str)
    
    # Print the length of the retrieved product list
    print(f"List_{number} has length: ", len(product_list))
    
    # Append the retrieved product list to the main product_lists list
    product_lists.append(product_list)
# Out:
# List_200 has length:  200
# List_400 has length:  200
# List_600 has length:  200
# List_800 has length:  200
# List_1000 has length:  200
# List_1200 has length:  93

# %% [markdown]
# ## Verification of Data:
# Printing the length of each product_list allows you to verify that you received the expected number of products from each API request. It helps ensure that the data retrieval process is working as expected.

# %%
for product_list in product_lists:
    print(len(product_list))
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 93

# %% [markdown]
# Description:
#
# - Initialization: The code starts by initializing an empty list named master_list, which will be used to store all the products from the individual product_lists.
#
# - Nested Loop: It then iterates over each product_list in the product_lists list using the outer loop. Within this loop, there is another loop that iterates over each product in the current product_list.
#
# - Combining Products: For each product in each product_list, the code appends the product to the master_list. This effectively combines all the individual product lists into a single list containing all the products.
#
# - Total Count: After iterating over all the product lists and appending all the products to the master_list, the code prints the total number of products in the master_list using the len() function.
#
# - This code snippet essentially flattens the list of lists (product_lists) into a single list (master_list) containing all the products from the individual lists. This can be useful for further processing or analysis where a single list of products is required.

# %%
master_list = []

for product_list in product_lists:
    for product in product_list:
        master_list.append(product)
print(len(master_list))
# Out:
# 1293

# %% [markdown]
# # Split Between Option and No Option
#
# Description:
#
# - Initialization: The code initializes two empty lists: Options and No_Options. These lists will be used to categorize products based on whether they have options or not.
#
# - Loop through Products: It then iterates over each product in the master_list, which contains all the products combined from the product_lists.
#
# - Check for Options: Within the loop, it checks whether each product has options or not. This is done by examining the length of the OptionSetList within each product dictionary.
#
# - Categorization: If a product has options (i.e., if the length of its OptionSetList is not zero), it is appended to the Options list. Otherwise, if the product has no options, it is appended to the No_Options list.
#
# - Result: At the end of the loop, the Options list will contain all products that have options, while the No_Options list will contain all products that do not have any options.

# %%
# Initialize empty lists to store products with options and products without options
Options = []
No_Options = []

# Iterate over each product in the master list
for product in master_list:
    # Check if the product has any options by inspecting the length of its OptionSetList
    if len(product['OptionSetList']) != 0:
        # If the product has options, append it to the Options list
        Options.append(product)
    else:
        # If the product has no options, append it to the No_Options list
        No_Options.append(product)

# %%
len(Options)
# Out:
# 516

# %%
len(No_Options)
# Out:
# 777

# %%
len(Options) + len(No_Options) == 1293
# Out:
# True

# %% [markdown]
# ## No Options Dataframe
#
# - Initialization: Several empty lists are initialized to store specific attributes of products that do not have options. These attributes include CatalogID, SKU, Name, whether the product is for sale (NotForSale), and whether it is hidden (Hide).
#
# - Extraction of Attributes: The code iterates over each product in the No_Options list, extracting the relevant attributes from each product dictionary. These attributes are then appended to their respective lists.
#
# - Combination of Attributes: After extracting the attributes for all products without options, the lists are combined into a dictionary named Products_No_Options. Each key in the dictionary represents an attribute (e.g., 'CatalogID', 'SKU'), and the corresponding value is a list containing the values of that attribute for all products.
#
# - Optional Output: Optionally, the extracted attributes can be printed to inspect their values. Additionally, the dictionary can be converted into a DataFrame (assuming Pandas is imported) and displayed for further analysis, showing the first 100 entries.

# %%
Products_No_Options = pd.DataFrame(columns = ['CatalogID','SKU','Name','Hide','NotForSale'])

# %%
# Initialize empty lists to store specific attributes of products without options
catalogid_list_noOptions = []
SKU_list_noOptions = []
Name_list_noOptions = []
sale_noOptions = []
hide_noOptions = []

# Iterate over each product in the No_Options list
for product in No_Options:
    # Extract relevant attributes from each product
    forsale = product['NotForSale']  # Retrieve the 'NotForSale' attribute
    hide = product['Hide']  # Retrieve the 'Hide' attribute
    catalogid = product['SKUInfo']['CatalogID']  # Retrieve the CatalogID from the SKUInfo dictionary
    SKU = product['SKUInfo']['SKU']  # Retrieve the SKU from the SKUInfo dictionary
    Name = product['SKUInfo']['Name']  # Retrieve the Name from the SKUInfo dictionary
    
    # Append extracted attributes to respective lists
    catalogid_list_noOptions.append(catalogid)
    SKU_list_noOptions.append(SKU)
    Name_list_noOptions.append(Name)
    sale_noOptions.append(forsale)
    hide_noOptions.append(hide)

# Combine extracted attributes into a DataFrame or dictionary
Products_No_Options = {
    'CatalogID': catalogid_list_noOptions,
    'SKU': SKU_list_noOptions,
    'Name': Name_list_noOptions,
    'Hide': hide_noOptions,
    'NotForSale': sale_noOptions
}
# Convert the dictionary into a DataFrame
Products_No_Options_df = pd.DataFrame(Products_No_Options)

# Display the extracted attributes (optional)
# print(catalogid_list_noOptions)
# print(SKU_list_noOptions)
# print(Name_list_noOptions)

# Optionally, convert the dictionary into a DataFrame and display the first 100 entries
Products_No_Options_df.head(100)
# Out:
#     CatalogID             SKU  \
# 0        3465       11.1005SF
# 1        3466         11.1032
# 2        3478        295SL100
# 3        3480        30.0215P
# 4        3481         30.2104
# 5        3491         6ELTUBE
# 6        3494         7ELTUBE
# 7        3497          9UTUBE
# 8        3499        ALPHA12S
# 9        3501         AMP-3PK
# 10       3502         AMP-3SK
# 11       3505          BR-990
# 12       3506          SA-365
# 13       3507          SA-361
# 14       3509       CRIMPTOOL
# 15       3526       ETFBSSN-P
# 16       3529         HOLESAW
# 17       3534     LD3-PERFOOT
# 18       3537          BR-930
# 19       3539         BR-959J
# 20       3543          LMTUBE
# 21       3549          PAP112
# 22       3551       ETHFSS-SP
# 23       3553         RBKTHD1
# 24       3554         RBKTHD2
# 25       3557         RBKTHD5
# 26       3558         RBKTHD6
# 27       3563         SC-1012
# 28       3564         SC-1022
# 29       3583          TACTL5
# 30       3584           TAM83
# 31       3585           TAL65
# 32       3586           TAL85
# 33       3596        TURBOASY
# 34       3597        UHF2150A
# 35       3598        SSFPOSC6
# 36       3600            UFM8
# 37       3609            WPA1
# 38       3610          WPA112
# 39       3616           5.556
# 40       3618          30.021
# 41       3619           30.22
# 42       3620          30.222
# 43       3700     LEDFLASHER1
# 44       3708         30.0219
# 45       3808       RUMBLER-3
# 46       3809        295SLSA1
# 47       3810           BETA1
# 48       3814        295SLSA6
# 49       3822           ULF44
# 50       3840       FUSEBLOCK
# 51       3841        FUSEHLDR
# 52       3866           81150
# 53       3908       CUP2-1006
# 54       3909       C-TMW-12E
# 55       3910       C-TMW-15E
# 56       3911       C-TMW-18E
# 57       3916          C-BL-4
# 58       3919          C-SW-1
# 59       3922       C-LP2-BL3
# 60       3926        CUP-1002
# 61       3927       CUP2-1001
# 62       3928           C-MCB
# 63       3929            C-MC
# 64       3931   ETHFSS-SP-IS0
# 65       3932          SA-385
# 66       3952         31.2515
# 67       3975          SC-409
# 68       3976          SC-407
# 69       3981         PCCS9LW
# 70       3983           PCC8R
# 71       4013         ST415CP
# 72       4042          GAMMA2
# 73       4045         TADCTL1
# 74       4049           DTA8A
# 75       4050           DTA6A
# 76       4051           TAM63
# 77       4052          DPTA6A
# 78       4053          DPTA8A
# 79       4054           TAZ66
# 80       4055           TAZ86
# 81       4068            604T
# 82       4069          604BTT
# 83       4073          M62BTT
# 84       4074            M62T
# 85       4075           M62BU
# 86       4076          704BTT
# 87       4077            704T
# 88       4083           69140
# 89       4084           75713
# 90       4085           44450
# 91       4088           44900
# 92       4105          BR-935
# 93       4123        9SC0ENZR
# 94       4126           M9LZC
# 95       4129        70C0ELZR
# 96       4147      ETSA481CSR
# 97       4150  PSI-12V-PROMAX
# 98       4158      LCS880-016
# 99       4219         TOGGLE5
#
#                                                                        Name  \
# 0                                 Sho Me Universal Strobe Style LED Flasher
# 1                             Sho Me Micro Switch with Built In LED Flasher
# 2           Whelen Full Function Hands Free Siren and Heavy Duty Microphone
# 3                                   Sho Me Concealed Scoop 100 Watt Speaker
# 4                                     Sho Me Four Function Undercover Siren
# 5                                                Whelen 6ELTUBE Strobe Tube
# 6                   Whelen 700 Series Linear Strobe Tube/Reflector Assembly
# 7                                Whelen Edge 9M/Ultra Corner Tube/Reflector
# 8                                             Whelen Alpha Hands Free Siren
# 9                                    Standard AMP Pin & Connector Kit  Male
# 10                               Standard AMP Socket & Connector Kit Female
# 11                        Brooking Industries 6 Button Digital Switch Panel
# 12                                             Carson SA 365 Defender Siren
# 13                                             Carson SA 361 Defender Siren
# 14                                          AMP Crimping and Stripping Tool
# 15                              SoundOff Signal Flashback Taillight Flasher
# 16                                            1" Hole Saw for Head/Tail LED
# 17                          Nova 3 Wire Strobe Cable by the Foot   18 Gauge
# 18           Brooking Industries 3 Outlet Accessory Box with Lighted Switch
# 19                                Brooking Industries 6 Function Switch Box
# 20                            Nova Linear Microthin Replacement Strobe Tube
# 21                                            Whelen Power Air Horn with PA
# 22                       SoundOff Signal Select A Pattern Headlight Flasher
# 23                            Whelen Harley Davidson Side Cowl Mounting Kit
# 24                       Whelen Harley Davidson Side Crash Bar Mounting Kit
# 25                      Whelen Harley Davidson Under Headlight Mounting Kit
# 26                    Whelen Harley Davidson Passing/Fog Light Mounting Kit
# 27                            Carson SC 1012 Volunteer Siren with Switchbox
# 28                   Carson SC 1022 Volunteer Siren with Built in Switchbox
# 29                                      Whelen Traffic Advisor Control Head
# 30                       Whelen 8 Lamp TIR3 Traffic Advisor with Controller
# 31            Whelen 6 Lamp LED Traffic Advisor Low Profile with Controller
# 32            Whelen 8 Lamp LED Traffic Advisor Low Profile with Controller
# 33                                              Whelen TURBOASY Strobe Tube
# 34                 Whelen Headlight/Grille Flasher for Positive or Negative
# 35                          Whelen Crown Victoria Plug in Headlight Flasher
# 36                          Whelen 8 Outlet Universal Halogen & LED Flasher
# 37                                   Whelen WPA1 Full Function Control Head
# 38                                         Whelen 100W Waterproof Amplifier
# 39                        Sho Me Nine Function Switch Box with Slide Switch
# 40                               Sho Me 100W Siren Standard Profile Speaker
# 41                 Sho Me Full Feature PLUS Dash Mount Siren (GE Powercall)
# 42                      Sho Me Warble Whoop Undercover Siren (GE Powercall)
# 43                                              Nova Universal LED Flasher
# 44                                Sho Me 100W Motorcycle Round Bell Speaker
# 45                      Federal Signal Rumbler Intersection Clearing System
# 46                    Whelen Hands Free Siren with 17 Scan Lock Siren Tones
# 47                                  Whelen BETA1 Full Function Control Head
# 48                             Whelen Hands Free Siren with 9 Switch Lights
# 49                          Whelen ULF44 LED Flasher with 62 Flash Patterns
# 50                                    ATO/ATC Ganged Fuse Block for 6 Fuses
# 51                                    Inline Watertight ATO/ATC Fuse Holder
# 52                                       Permatex Dielectric Tune Up Grease
# 53                                  Havis Dual External Cup Holder 25° Bend
# 54                                 Havis 12" Long 8" Wide Tunnel Mount Base
# 55                                 Havis 15" Long 8" Wide Tunnel Mount Base
# 56                                 Havis 18" Long 8" Wide Tunnel Mount Base
# 57                                                Havis 2 or 4 Switch Plate
# 58                                           Havis Rocker Switch with Light
# 59                                 Havis 2 Lighter Plug with 2 Switch Plate
# 60                                            Havis Dual External Cupholder
# 61                                           Havis Dual Internal Cup Holder
# 62                                            Havis Microphone Clip Bracket
# 63                                                    Havis Microphone Clip
# 64                              SoundOff Signal Isolation Headlight Flasher
# 65                           Carson SA 385 Alert Full Feature Siren with PA
# 66                  Sho Me 8 Function Undercover Siren with Mini Controller
# 67                                            Carson SC 409 Commander Siren
# 68                                            Carson SC  407 Enforcer Siren
# 69         Whelen Programmable Switch for Liberty II & Freedom IV Lightbars
# 70                       Whelen 8 Position Key Pad with Remote Relay Module
# 71                              Star/SVP Clear Hide Away Pop In Strobe Tube
# 72                                            Whelen Gamma2 Siren/Switchbox
# 73                        Whelen TADCTL1 Control Head for use with TAD/TADP
# 74                  Whelen Dominator 8 Lamp Traffic Advisor  TIR3 Super LED
# 75                  Whelen Dominator 6 Lamp Traffic Advisor  TIR3 Super LED
# 76           Whelen 6 Lamp Traffic Advisor  TIR3  Super LED with Controller
# 77             Whelen Dominator Plus 6 Lamp LINZ6 Super LED Traffic Advisor
# 78             Whelen Dominator Plus 8 Lamp LINZ6 Super LED Traffic Advisor
# 79            Whelen 6 Lamp LINZ6 Super LED Traffic Advisor with Controller
# 80            Whelen 8 Lamp LINZ6 Super LED Traffic Advisor with Controller
# 81                                   Whelen 600 Series Super LED Amber Turn
# 82                              Whelen 600 Series Super LED Brake/Tail/Turn
# 83                                      Whelen M6 Super LED Brake/Tail/Turn
# 84                                           Whelen M6 Super LED Amber Turn
# 85                                 Whelen M6 Super LED Backup/Reverse Light
# 86                                     Whelen 700 Super LED Brake/Tail/Turn
# 87                                          Whelen 700 Super LED Amber Turn
# 88                          Streamlight Vantage C4 LED Helmet Mounted Light
# 89                       Streamlight Stinger C4 LED Rechargeable Flashlight
# 90                      Streamlight Fire Vulcan C4 LED Rechargeable Lantern
# 91            Streamlight WayPoint Pistol Grip Spotlight with DC Power Cord
# 92                      Brooking Industries Universal Lighted Rocker Switch
# 93                               Whelen 900 Series Gradient Opti Scenelight
# 94                                           Whelen M9 Super LED Scenelight
# 95                               Whelen 700 Series Gradient Opti Scenelight
# 96  SoundOff Signal nERGY 400 Series Multi Function Siren with Knob Control
# 97                      PriorityStart! ProMax 12V Battery Protection System
# 98                                 Star/SVP Handheld Unistar Command Center
# 99                                       Universal Lighted Toggle Switch #5
#
#      Hide  NotForSale
# 0   False       False
# 1   False       False
# 2   False       False
# 3   False       False
# 4   False       False
# 5   False       False
# 6   False       False
# 7   False       False
# 8   False       False
# 9   False       False
# 10  False       False
# 11  False       False
# 12  False       False
# 13  False       False
# 14  False       False
# 15  False       False
# 16  False       False
# 17  False       False
# 18  False       False
# 19  False       False
# 20  False       False
# 21  False       False
# 22  False       False
# 23  False       False
# 24  False       False
# 25  False       False
# 26  False       False
# 27  False       False
# 28  False       False
# 29  False       False
# 30  False       False
# 31  False       False
# 32  False       False
# 33  False       False
# 34  False       False
# 35  False       False
# 36  False       False
# 37  False       False
# 38  False       False
# 39  False       False
# 40  False       False
# 41  False       False
# 42  False       False
# 43  False       False
# 44  False       False
# 45  False       False
# 46  False       False
# 47  False       False
# 48  False       False
# 49  False       False
# 50  False       False
# 51  False       False
# 52  False       False
# 53  False       False
# 54  False       False
# 55  False       False
# 56  False       False
# 57  False       False
# 58  False       False
# 59  False       False
# 60  False       False
# 61  False       False
# 62  False       False
# 63  False       False
# 64  False       False
# 65  False       False
# 66  False       False
# 67  False       False
# 68  False       False
# 69  False       False
# 70  False       False
# 71  False       False
# 72  False       False
# 73  False       False
# 74  False       False
# 75  False       False
# 76  False       False
# 77  False       False
# 78  False       False
# 79  False       False
# 80  False       False
# 81  False       False
# 82  False       False
# 83  False       False
# 84  False       False
# 85  False       False
# 86  False       False
# 87  False       False
# 88  False       False
# 89  False       False
# 90  False       False
# 91  False       False
# 92  False       False
# 93  False       False
# 94  False       False
# 95  False       False
# 96  False       False
# 97  False       False
# 98  False       False
# 99  False       False

# %%
len(Products_No_Options_df)
# Out:
# 777

# %% [markdown]
# # Options Dataframe
#
# - Initialization: Two empty lists df_list and df_list_2 are initialized to store DataFrames. df_list is for products with options, and df_list_2 is for products without options.
#
# - Iterating over Products: The code iterates over each product in the Options list, extracting common attributes like catalog ID, SKU, name, whether it's for sale (NotForSale), and whether it's hidden (Hide).
#
# - Option Extraction: For each product, it extracts option data if any, creating a DataFrame options_df to store this information.
#
# - Concatenation: If options exist for a product, it concatenates the product DataFrame (product_df) with the options DataFrame - (options_df) and appends it to df_list. Otherwise, it appends the product DataFrame to df_list_2.
#
# - Concatenating DataFrames: After iterating over all products, if df_list is not empty, it concatenates all DataFrames within - df_list into a single DataFrame Options_df. It also concatenates DataFrames in df_list_2 into Options_df_2.
#
# - Data Type Conversion: It converts the 'Hidden' column to integer type for both Options_df and Options_df_2.
#
# - Output: Finally, it prints the first 100 entries of the final DataFrame Options_df containing products with options, or prints a message if df_list is empty indicating no data to concatenate.

# %%
df_list = []
df_list_2 = []

for product in Options:
    catalog_id = product['SKUInfo']['CatalogID']
    sku = product['SKUInfo']['SKU']
    name = product['SKUInfo']['Name']
    forsale = product['NotForSale']
    not_on_site = product['Hide']
    
    # Initialize product_df with default 'Hidden' value
    product_df = pd.DataFrame({
        'CatalogID': [catalog_id],
        'SKU': [sku],
        'Name': [name],
        'NotForSale': [forsale],
        'Hide': [not_on_site],  # Add Hide column with default value
    })

    option_data = []
    for option in product['OptionSetList']:
        option_set_id = option['OptionSetID']
        option_sorting = option['OptionSorting']
        option_list = option['OptionList']
        hidden_options = [option['OptionHide'] for option in option_list]
        option_names = [option['OptionName'] for option in option_list]
        partnumbers = [option['OptionPartNumber'] for option in option_list]

        option_data.extend(list(zip(option_names, partnumbers, [option_set_id] * len(option_list), [option_sorting] * len(option_list), hidden_options)))

    options_df = pd.DataFrame(option_data, columns=['OptionName', 'OptionPartNumber', 'OptionSetID', 'OptionSorting', 'Hidden'])

    if not options_df.empty:
        product_df = pd.concat([product_df] * len(options_df), ignore_index=True)
        result_df = pd.concat([product_df, options_df], axis=1)
        df_list.append(result_df)
    else:
        df_list_2.append(product_df)

# Concatenate all data frames in df_list if it is not empty
if df_list:
    Options_df = pd.concat(df_list, ignore_index=True)
    Options_df_2 = pd.concat(df_list_2, ignore_index=True)
    Options_df['Hidden'] = Options_df['Hidden'].astype(int)
    Options_df_2['Hidden'] = Options_df_2['Hide'].astype(int)  # Use 'Hide' column for Options_df_2
    # Print the final DataFrame
    Options_df.head(100)
else:
    print("No data to concatenate.")

# %%
Options_df.head()
# Out:
#    CatalogID      SKU                                    Name  NotForSale  \
# 0       3457     RB6T  Whelen Dual Reflector Rota Beam Beacon       False
# 1       3457     RB6T  Whelen Dual Reflector Rota Beam Beacon       False
# 2       3457     RB6T  Whelen Dual Reflector Rota Beam Beacon       False
# 3       3457     RB6T  Whelen Dual Reflector Rota Beam Beacon       False
# 4       3474  11.1002    Sho Me Universal On/Off/Flash Switch       False
#
#     Hide          OptionName OptionPartNumber  OptionSetID  OptionSorting  \
# 0  False                Blue               BP         2451              0
# 1  False               Clear               CP         2451              0
# 2  False                 Red               RP         2451              0
# 3  False               Amber               AP         2451              0
# 4  False  Positive Momentary              .PM         4114              1
#
#    Hidden
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %%
len(Options_df['CatalogID'].unique())
# Out:
# 509

# %%
len(Options_df)
# Out:
# 4389

# %%
Options_df['Hide'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# # Filtering by products on the website

# %%
Products_Options_onWebsite = Options_df[Options_df['Hide'] == False]

# %%
len(Products_Options_onWebsite)
# Out:
# 3955

# %%
Products_Options_onWebsite.head()
# Out:
#    CatalogID      SKU                                    Name  NotForSale  \
# 0       3457     RB6T  Whelen Dual Reflector Rota Beam Beacon       False
# 1       3457     RB6T  Whelen Dual Reflector Rota Beam Beacon       False
# 2       3457     RB6T  Whelen Dual Reflector Rota Beam Beacon       False
# 3       3457     RB6T  Whelen Dual Reflector Rota Beam Beacon       False
# 4       3474  11.1002    Sho Me Universal On/Off/Flash Switch       False
#
#     Hide          OptionName OptionPartNumber  OptionSetID  OptionSorting  \
# 0  False                Blue               BP         2451              0
# 1  False               Clear               CP         2451              0
# 2  False                 Red               RP         2451              0
# 3  False               Amber               AP         2451              0
# 4  False  Positive Momentary              .PM         4114              1
#
#    Hidden
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %% [markdown]
# # No Options Products

# %% [markdown]
# Here it was discovered that due to string complications these 6 products did not make it to the no options dataframe. These were added to the master no options list.

# %%
len(Options_df_2['CatalogID'].unique())
# Out:
# 6

# %%
Options_df_2 = Options_df_2[['CatalogID','SKU','Name','Hide','NotForSale']]

# %%
Options_df_2
# Out:
#    CatalogID         SKU                                           Name  \
# 0       3951    JF0BAAAA               Whelen Towman's Justice Lightbar
# 1       6985  GARAGE-MB1                Federal Signal MB1  Message Bar
# 2       7001      R-4600                    Feniex Reverse Lux 6x4" LED
# 3       7002      R-3700                    Feniex Reverse Lux 7x3" LED
# 4       7003      R-7900                    Feniex Reverse Lux 9x7" LED
# 5       7004     BTT-3XB  Feniex Backup/Brake/Tail Turn/Reverse LUX LED
#
#    NotForSale   Hide  Hidden
# 0       False  False       0
# 1        True   True       1
# 2       False  False       0
# 3       False  False       0
# 4       False  False       0
# 5       False  False       0

# %%
AllSKUs_No_Options = pd.concat([Products_No_Options_df,Options_df_2])
AllSKUs_No_Options = AllSKUs_No_Options[['CatalogID','SKU','Name','Hide','NotForSale']]

# %%
AllSKUs_No_Options.to_csv('SKUs_No_Options.csv')

# %%
SKUs_No_Options = pd.read_csv('SKUs_No_Options.csv')
SKUs_No_Options.head(20)
# Options_df_2 = Options_df_2[['CatalogID','SKU','Name']]
# Out:
#     Unnamed: 0  CatalogID          SKU  \
# 0            0       3465    11.1005SF
# 1            1       3466      11.1032
# 2            2       3478     295SL100
# 3            3       3480     30.0215P
# 4            4       3481      30.2104
# 5            5       3491      6ELTUBE
# 6            6       3494      7ELTUBE
# 7            7       3497       9UTUBE
# 8            8       3499     ALPHA12S
# 9            9       3501      AMP-3PK
# 10          10       3502      AMP-3SK
# 11          11       3505       BR-990
# 12          12       3506       SA-365
# 13          13       3507       SA-361
# 14          14       3509    CRIMPTOOL
# 15          15       3526    ETFBSSN-P
# 16          16       3529      HOLESAW
# 17          17       3534  LD3-PERFOOT
# 18          18       3537       BR-930
# 19          19       3539      BR-959J
#
#                                                                Name   Hide  \
# 0                         Sho Me Universal Strobe Style LED Flasher  False
# 1                     Sho Me Micro Switch with Built In LED Flasher  False
# 2   Whelen Full Function Hands Free Siren and Heavy Duty Microphone  False
# 3                           Sho Me Concealed Scoop 100 Watt Speaker  False
# 4                             Sho Me Four Function Undercover Siren  False
# 5                                        Whelen 6ELTUBE Strobe Tube  False
# 6           Whelen 700 Series Linear Strobe Tube/Reflector Assembly  False
# 7                        Whelen Edge 9M/Ultra Corner Tube/Reflector  False
# 8                                     Whelen Alpha Hands Free Siren  False
# 9                            Standard AMP Pin & Connector Kit  Male  False
# 10                       Standard AMP Socket & Connector Kit Female  False
# 11                Brooking Industries 6 Button Digital Switch Panel  False
# 12                                     Carson SA 365 Defender Siren  False
# 13                                     Carson SA 361 Defender Siren  False
# 14                                  AMP Crimping and Stripping Tool  False
# 15                      SoundOff Signal Flashback Taillight Flasher  False
# 16                                    1" Hole Saw for Head/Tail LED  False
# 17                  Nova 3 Wire Strobe Cable by the Foot   18 Gauge  False
# 18   Brooking Industries 3 Outlet Accessory Box with Lighted Switch  False
# 19                        Brooking Industries 6 Function Switch Box  False
#
#     NotForSale
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False

# %% [markdown]
# # Filtering Options dataframe by less than 8 products
#
# After initial delivery, client agreed that we want less than 8 options for the products.

# %%
import pandas as pd

# Assuming df_options_ is your DataFrame
# Replace 'catalogid_column_name' with the actual column name containing catalogid
# Replace 'sorting_column_name' with the actual column name containing sorting values

catalogid_column_name = 'CatalogID'
sorting_column_name = 'OptionSorting'

# Create variables to store the catalogids with up to 8 unique values
catalogids_with_up_to_8_unique_options = []

# Iterate through unique catalogids in the DataFrame
for catalogid in Products_Options_onWebsite[catalogid_column_name].unique():
    # Filter DataFrame for the current catalogid
    catalogid_data = Products_Options_onWebsite[Products_Options_onWebsite[catalogid_column_name] == catalogid]

    # Count the number of unique sorting values
    unique_sorting_count = len(catalogid_data[sorting_column_name].unique())

    # Check if the current catalogid has up to 8 unique values
    if unique_sorting_count <= 8:
        catalogids_with_up_to_8_unique_options.append(catalogid)

# Filter the original DataFrame based on the selected catalogids
filtered_df = Products_Options_onWebsite[Products_Options_onWebsite[catalogid_column_name].isin(catalogids_with_up_to_8_unique_options)]

# %%
len(filtered_df)
# Out:
# 3734

# %%
filtered_df
# Out:
#       CatalogID                     SKU  \
# 0          3457                    RB6T
# 1          3457                    RB6T
# 2          3457                    RB6T
# 3          3457                    RB6T
# 4          3474                 11.1002
# 5          3474                 11.1002
# 6          3475                  11.120
# 7          3475                  11.120
# 8          3475                  11.120
# 9          3475                  11.120
# 10         3475                  11.120
# 11         3475                  11.120
# 12         3475                  11.120
# 13         3475                  11.120
# 14         3475                  11.120
# 15         3475                  11.120
# 16         3475                  11.120
# 17         3479                       2
# 18         3479                       2
# 19         3479                       2
# 20         3479                       2
# 21         3479                       2
# 22         3479                       2
# 23         3479                       2
# 24         3479                       2
# 25         3479                       2
# 26         3479                       2
# 27         3483                      68
# 28         3483                      68
# 29         3483                      68
# 30         3483                      68
# 31         3483                      68
# 32         3483                      68
# 33         3483                      68
# 34         3483                      68
# 35         3483                      68
# 36         3485                      50
# 37         3485                      50
# 38         3485                      50
# 39         3485                      50
# 40         3485                      50
# 41         3485                      50
# 42         3486                      50
# 43         3486                      50
# 44         3486                      50
# 45         3486                      50
# 46         3486                      50
# 47         3486                      50
# 48         3486                      50
# 49         3486                      50
# 50         3487                      68
# 51         3487                      68
# 52         3487                      68
# 53         3487                      68
# 54         3487                      68
# 55         3487                      68
# 56         3487                      68
# 57         3487                      68
# 58         3487                      68
# 59         3487                      68
# 60         3487                      68
# 61         3489                      60
# 62         3489                      60
# 63         3489                      60
# 64         3489                      60
# 65         3489                      60
# 66         3489                      60
# 67         3489                      60
# 68         3489                      60
# 69         3489                      60
# 70         3489                      60
# 71         3489                      60
# 72         3489                      60
# 73         3489                      60
# 74         3490                      68
# 75         3490                      68
# 76         3490                      68
# 77         3490                      68
# 78         3490                      68
# 79         3490                      68
# 80         3490                      68
# 81         3490                      68
# 82         3490                      68
# 83         3492                      70
# 84         3492                      70
# 85         3492                      70
# 86         3492                      70
# 87         3492                      70
# 88         3492                      70
# 89         3492                      70
# 90         3492                      70
# 91         3492                      70
# 92         3492                      70
# 93         3492                      70
# 94         3492                      70
# 95         3493                      68
# 96         3493                      68
# 97         3493                      68
# 98         3493                      68
# 99         3493                      68
# 100        3493                      68
# 101        3493                      68
# 102        3495                      90
# 103        3495                      90
# 104        3495                      90
# 105        3495                      90
# 106        3495                      90
# 107        3495                      90
# 108        3495                      90
# 109        3495                      90
# 110        3495                      90
# 111        3495                      90
# 112        3495                      90
# 113        3496                      68
# 114        3496                      68
# 115        3496                      68
# 116        3496                      68
# 117        3496                      68
# 118        3496                      68
# 119        3496                      68
# 120        3496                      68
# 121        3500                   ALPHA
# 122        3500                   ALPHA
# 123        3500                   ALPHA
# 124        3500                   ALPHA
# 125        3500                   ALPHA
# 126        3508                  SA-441
# 127        3508                  SA-441
# 128        3510                      D2
# 129        3510                      D2
# 130        3510                      D2
# 131        3510                      D2
# 132        3510                      D2
# 133        3510                      D2
# 134        3510                      D2
# 135        3510                      D2
# 136        3510                      D2
# 137        3527                     HAF
# 138        3527                     HAF
# 139        3527                     HAF
# 140        3527                     HAF
# 141        3527                     HAF
# 142        3527                     HAF
# 143        3531                     L22
# 144        3531                     L22
# 145        3531                     L22
# 146        3531                     L22
# 147        3531                     L22
# 148        3531                     L22
# 149        3531                     L22
# 150        3531                     L22
# 151        3531                     L22
# 152        3542              LINEARMT-C
# 153        3542              LINEARMT-C
# 154        3542              LINEARMT-C
# 155        3542              LINEARMT-C
# 156        3542              LINEARMT-C
# 157        3542              LINEARMT-C
# 158        3542              LINEARMT-C
# 159        3542              LINEARMT-C
# 160        3542              LINEARMT-C
# 161        3542              LINEARMT-C
# 162        3542              LINEARMT-C
# 163        3545                    M4B6
# 164        3545                    M4B6
# 165        3545                    M4B6
# 166        3545                    M4B6
# 167        3545                    M4B6
# 168        3545                    M4B6
# 169        3545                    M4B6
# 170        3545                    M4B6
# 171        3545                    M4B6
# 172        3552                    R2LP
# 173        3552                    R2LP
# 174        3552                    R2LP
# 175        3552                    R2LP
# 176        3552                    R2LP
# 177        3552                    R2LP
# 178        3552                    R2LP
# 179        3556                 RBKTHD4
# 180        3556                 RBKTHD4
# 181        3560                  SA315U
# 182        3560                  SA315U
# 183        3560                  SA315U
# 184        3560                  SA315U
# 185        3560                  SA315U
# 186        3560                  SA315U
# 187        3560                  SA315U
# 188        3560                  SA315U
# 189        3560                  SA315U
# 190        3560                  SA315U
# 191        3560                  SA315U
# 192        3560                  SA315U
# 193        3560                  SA315U
# 194        3560                  SA315U
# 195        3560                  SA315U
# 196        3560                  SA315U
# 197        3560                  SA315U
# 198        3560                  SA315U
# 199        3560                  SA315U
# 200        3560                  SA315U
# 201        3560                  SA315U
# 202        3560                  SA315U
# 203        3560                  SA315U
# 204        3560                  SA315U
# 205        3560                  SA315U
# 206        3560                  SA315U
# 207        3560                  SA315U
# 208        3560                  SA315U
# 209        3560                  SA315U
# 210        3560                  SA315U
# 211        3560                  SA315U
# 212        3560                  SA315U
# 213        3560                  SA315U
# 214        3560                  SA315U
# 215        3560                  SA315U
# 216        3560                  SA315U
# 217        3560                  SA315U
# 218        3560                  SA315U
# 219        3560                  SA315U
# 220        3561                  SA350M
# 221        3565                  SC-550
# 222        3565                  SC-550
# 223        3566                  SLWIC3
# 224        3566                  SLWIC3
# 225        3566                  SLWIC3
# 226        3566                  SLWIC3
# 227        3566                  SLWIC3
# 228        3567                 XSLMINI
# 229        3567                 XSLMINI
# 230        3568                   SLPMM
# 231        3568                   SLPMM
# 232        3568                   SLPMM
# 233        3568                   SLPMM
# 234        3568                   SLPMM
# 235        3568                   SLPMM
# 236        3568                   SLPMM
# 237        3568                   SLPMM
# 238        3568                   SLPMM
# 239        3568                   SLPMM
# 240        3569                 SLULTRA
# 241        3569                 SLULTRA
# 242        3571                    SMLL
# 243        3571                    SMLL
# 244        3571                    SMLL
# 245        3571                    SMLL
# 246        3571                    SMLL
# 247        3571                    SMLL
# 248        3701                       R
# 249        3701                       R
# 250        3701                       R
# 251        3701                       R
# 252        3701                       R
# 253        3701                       R
# 254        3701                       R
# 255        3707                IW0BAAAA
# 256        3707                IW0BAAAA
# 257        3707                IW0BAAAA
# 258        3707                IW0BAAAA
# 259        3707                IW0BAAAA
# 260        3707                IW0BAAAA
# 261        3707                IW0BAAAA
# 262        3707                IW0BAAAA
# 263        3707                IW0BAAAA
# 264        3707                IW0BAAAA
# 265        3707                IW0BAAAA
# 266        3707                IW0BAAAA
# 267        3750                    M07T
# 268        3750                    M07T
# 269        3750                    M07T
# 270        3750                    M07T
# 271        3750                    M07T
# 272        3751                    L31H
# 273        3751                    L31H
# 274        3751                    L31H
# 275        3751                    L31H
# 276        3751                    L31H
# 277        3751                    L31H
# 278        3751                    L31H
# 279        3753                      40
# 280        3753                      40
# 281        3753                      40
# 282        3753                      40
# 283        3753                      40
# 284        3753                      40
# 285        3753                      40
# 286        3753                      40
# 287        3753                      40
# 288        3753                      40
# 289        3753                      40
# 290        3753                      40
# 291        3754                      40
# 292        3754                      40
# 293        3754                      40
# 294        3754                      40
# 295        3754                      40
# 296        3754                      40
# 297        3754                      40
# 298        3754                      40
# 299        3794                   PA300
# 300        3794                   PA300
# 301        3816                     VTX
# 302        3816                     VTX
# 303        3816                     VTX
# 304        3816                     VTX
# 305        3816                     VTX
# 306        3816                     VTX
# 307        3816                     VTX
# 308        3816                     VTX
# 309        3816                     VTX
# 310        3816                     VTX
# 368        3818                     MJE
# 369        3818                     MJE
# 370        3818                     MJE
# 371        3818                     MJE
# 372        3818                     MJE
# 373        3818                     MJE
# 374        3819                    SCUP
# 375        3819                    SCUP
# 376        3824                      M4
# 377        3824                      M4
# 378        3824                      M4
# 379        3824                      M4
# 380        3824                      M4
# 381        3824                      M4
# 382        3824                      M4
# 383        3824                      M4
# 384        3824                      M4
# 385        3824                      M4
# 386        3824                      M4
# 387        3828                      M6
# 388        3828                      M6
# 389        3828                      M6
# 390        3828                      M6
# 391        3828                      M6
# 392        3828                      M6
# 393        3828                      M6
# 394        3828                      M6
# 395        3828                      M6
# 396        3828                      M6
# 397        3828                      M6
# 398        3828                      M6
# 399        3828                      M6
# 400        3832                      M9
# 401        3832                      M9
# 402        3832                      M9
# 403        3832                      M9
# 404        3832                      M9
# 405        3832                      M9
# 406        3832                      M9
# 407        3832                      M9
# 408        3832                      M9
# 409        3832                      M9
# 410        3832                      M9
# 411        3842                 PRIWIRE
# 412        3842                 PRIWIRE
# 413        3842                 PRIWIRE
# 414        3842                 PRIWIRE
# 415        3842                 PRIWIRE
# 416        3842                 PRIWIRE
# 417        3842                 PRIWIRE
# 418        3850                WIRELOOM
# 419        3850                WIRELOOM
# 420        3850                WIRELOOM
# 421        3850                WIRELOOM
# 422        3850                WIRELOOM
# 423        3856              NYLONBUTT-
# 424        3856              NYLONBUTT-
# 425        3856              NYLONBUTT-
# 426        3856              NYLONBUTT-
# 427        3861         HEATSHRINKBUTT-
# 428        3861         HEATSHRINKBUTT-
# 429        3861         HEATSHRINKBUTT-
# 430        3861         HEATSHRINKBUTT-
# 431        3907             C-AS-840-11
# 432        3930                   C-EB-
# 433        3936                  HOWLER
# 434        3936                  HOWLER
# 435        3936                  HOWLER
# 436        3936                  HOWLER
# 437        3936                  HOWLER
# 438        3936                  HOWLER
# 439        3936                  HOWLER
# 440        3936                  HOWLER
# 441        3936                  HOWLER
# 442        3936                  HOWLER
# 443        3936                  HOWLER
# 444        3936                  HOWLER
# 445        3936                  HOWLER
# 446        3936                  HOWLER
# 447        3936                  HOWLER
# 448        3936                  HOWLER
# 449        3936                  HOWLER
# 450        3936                  HOWLER
# 451        3936                  HOWLER
# 452        3936                  HOWLER
# 453        3937                      D4
# 454        3937                      D4
# 455        3937                      D4
# 456        3937                      D4
# 457        3937                      D4
# 458        3937                      D4
# 459        3937                      D4
# 460        3937                      D4
# 461        3937                      D4
# 462        3937                      D4
# 463        3937                      D4
# 464        3937                      D4
# 465        3937                      D4
# 466        3937                      D4
# 467        3937                      D4
# 468        3937                      D4
# 469        3938                      D6
# 470        3938                      D6
# 471        3938                      D6
# 472        3938                      D6
# 473        3938                      D6
# 474        3938                      D6
# 475        3938                      D6
# 476        3938                      D6
# 477        3938                      D6
# 478        3938                      D6
# 479        3938                      D6
# 480        3938                      D6
# 481        3938                      D6
# 482        3938                      D6
# 483        3938                      D6
# 484        3938                      D6
# 485        3938                      D6
# 486        3938                      D6
# 487        3938                      D6
# 488        3938                      D6
# 489        3938                      D6
# 490        3938                      D6
# 491        3938                      D6
# 492        3938                      D6
# 493        3939                      D8
# 619        3995                     M7D
# 620        4008                  HA-150
# 621        4008                  HA-150
# 622        4023              SOLOXLP-IX
# 623        4023              SOLOXLP-IX
# 624        4023              SOLOXLP-IX
# 625        4023              SOLOXLP-IX
# 626        4023              SOLOXLP-IX
# 627        4023              SOLOXLP-IX
# 628        4023              SOLOXLP-IX
# 629        4023              SOLOXLP-IX
# 630        4023              SOLOXLP-IX
# 631        4023              SOLOXLP-IX
# 632        4023              SOLOXLP-IX
# 633        4023              SOLOXLP-IX
# 634        4023              SOLOXLP-IX
# 635        4023              SOLOXLP-IX
# 636        4023              SOLOXLP-IX
# 637        4023              SOLOXLP-IX
# 638        4023              SOLOXLP-IX
# 639        4023              SOLOXLP-IX
# 640        4023              SOLOXLP-IX
# 641        4023              SOLOXLP-IX
# 642        4023              SOLOXLP-IX
# 643        4023              SOLOXLP-IX
# 644        4023              SOLOXLP-IX
# 645        4023              SOLOXLP-IX
# 646        4023              SOLOXLP-IX
# 647        4023              SOLOXLP-IX
# 648        4023              SOLOXLP-IX
# 649        4023              SOLOXLP-IX
# 650        4023              SOLOXLP-IX
# 651        4023              SOLOXLP-IX
# 652        4023              SOLOXLP-IX
# 653        4023              SOLOXLP-IX
# 654        4023              SOLOXLP-IX
# 655        4023              SOLOXLP-IX
# 656        4023              SOLOXLP-IX
# 657        4023              SOLOXLP-IX
# 658        4023              SOLOXLP-IX
# 659        4023              SOLOXLP-IX
# 660        4023              SOLOXLP-IX
# 661        4024                       0
# 662        4024                       0
# 663        4024                       0
# 664        4024                       0
# 665        4024                       0
# 666        4024                       0
# 667        4024                       0
# 668        4024                       0
# 669        4024                       0
# 670        4024                       0
# 671        4024                       0
# 672        4056                  ENT2B3
# 673        4056                  ENT2B3
# 674        4056                  ENT2B3
# 675        4056                  ENT2B3
# 676        4056                  ENT2B3
# 677        4056                  ENT2B3
# 678        4056                  ENT2B3
# 679        4056                  ENT2B3
# 680        4056                  ENT2B3
# 681        4066                  EGHST1
# 682        4066                  EGHST1
# 683        4066                  EGHST1
# 684        4066                  EGHST1
# 685        4066                  EGHST1
# 686        4066                  EGHST1
# 687        4066                  EGHST1
# 688        4066                  EGHST1
# 691        4078                   70C00
# 692        4078                   70C00
# 693        4087                     905
# 694        4087                     905
# 695        4089                  NSP-11
# 696        4089                  NSP-11
# 697        4089                  NSP-11
# 698        4089                  NSP-11
# 699        4089                  NSP-11
# 700        4089                  NSP-11
# 701        4089                  NSP-11
# 702        4096              ATOMICROOF
# 703        4096              ATOMICROOF
# 704        4096              ATOMICROOF
# 705        4096              ATOMICROOF
# 706        4096              ATOMICROOF
# 707        4096              ATOMICROOF
# 708        4096              ATOMICROOF
# 709        4096              ATOMICROOF
# 710        4096              ATOMICROOF
# 711        4096              ATOMICROOF
# 712        4096              ATOMICROOF
# 713        4096              ATOMICROOF
# 714        4096              ATOMICROOF
# 715        4096              ATOMICROOF
# 716        4096              ATOMICROOF
# 717        4096              ATOMICROOF
# 718        4107                    EPL7
# 719        4107                    EPL7
# 720        4107                    EPL7
# 721        4107                    EPL7
# 722        4107                    EPL7
# 723        4107                    EPL7
# 724        4107                    EPL7
# 725        4136                     F4N
# 726        4136                     F4N
# 727        4136                     F4N
# 728        4136                     F4N
# 729        4136                     F4N
# 730        4136                     F4N
# 731        4136                     F4N
# 732        4136                     F4N
# 733        4136                     F4N
# 734        4136                     F4N
# 735        4136                     F4N
# 736        4136                     F4N
# 737        4136                     F4N
# 738        4136                     F4N
# 739        4136                     F4N
# 740        4136                     F4N
# 741        4136                     F4N
# 742        4136                     F4N
# 743        4136                     F4N
# 744        4136                     F4N
# 745        4136                     F4N
# 746        4136                     F4N
# 747        4136                     F4N
# 748        4136                     F4N
# 749        4136                     F4N
# 750        4136                     F4N
# 751        4136                     F4N
# 752        4136                     F4N
# 753        4136                     F4N
# 754        4136                     F4N
# 755        4136                     F4N
# 756        4136                     F4N
# 757        4136                     F4N
# 758        4136                     F4N
# 759        4136                     F4N
# 760        4136                     F4N
# 761        4136                     F4N
# 762        4136                     F4N
# 763        4136                     F4N
# 764        4136                     F4N
# 765        4136                     F4N
# 766        4136                     F4N
# 767        4136                     F4N
# 768        4136                     F4N
# 769        4136                     F4N
# 770        4136                     F4N
# 771        4136                     F4N
# 772        4136                     F4N
# 773        4136                     F4N
# 774        4136                     F4N
# 775        4136                     F4N
# 776        4136                     F4N
# 777        4136                     F4N
# 778        4136                     F4N
# 779        4136                     F4N
# 780        4136                     F4N
# 781        4183                  ELB45B
# 782        4183                  ELB45B
# 783        4183                  ELB45B
# 784        4183                  ELB45B
# 785        4190                    L32L
# 786        4190                    L32L
# 787        4190                    L32L
# 788        4190                    L32L
# 789        4190                    L32L
# 790        4190                    L32L
# 791        4190                    L32L
# 792        4193                      M2
# 793        4193                      M2
# 794        4193                      M2
# 795        4193                      M2
# 796        4193                      M2
# 797        4193                      M2
# 798        4193                      M2
# 799        4193                      M2
# 800        4193                      M2
# 801        4193                      M2
# 802        4198                   PFP1A
# 803        4198                   PFP1A
# 804        4198                   PFP1A
# 805        4200                   PFP2A
# 806        4200                   PFP2A
# 807        4200                   PFP2A
# 808        4201                   PSP1A
# 809        4201                   PSP1A
# 810        4201                   PSP1A
# 811        4201                   PSP1A
# 812        4205                      PB
# 813        4205                      PB
# 814        4205                      PB
# 815        4205                      PB
# 816        4206                  PBAPED
# 817        4206                  PBAPED
# 818        4206                  PBAPED
# 819        4206                  PBAPED
# 820        4207                    L41A
# 821        4207                    L41A
# 822        4207                    L41A
# 823        4253                  ES100C
# 824        4278                   CCSRN
# 825        4278                   CCSRN
# 826        4278                   CCSRN
# 835        4289                      MP
# 836        4289                      MP
# 837        4289                      MP
# 838        4289                      MP
# 839        4289                      MP
# 840        4289                      MP
# 841        4289                      MP
# 842        4289                      MP
# 843        4289                      MP
# 844        4289                      MP
# 845        4290                    PSL1
# 846        4290                    PSL1
# 847        4290                    PSL1
# 848        4290                    PSL1
# 849        4290                    PSL1
# 850        4290                    PSL1
# 851        4290                    PSL1
# 852        4290                    PSL1
# 853        4291                  ENFSSS
# 854        4291                  ENFSSS
# 855        4291                  ENFSSS
# 856        4291                  ENFSSS
# 857        4291                  ENFSSS
# 858        4291                  ENFSSS
# 859        4291                  ENFSSS
# 860        4291                  ENFSSS
# 861        4291                  ENFSSS
# 862        4291                  ENFSSS
# 863        4291                  ENFSSS
# 864        4291                  ENFSSS
# 865        4291                  ENFSSS
# 866        4291                  ENFSSS
# 867        4297                   ULB24
# 868        4297                   ULB24
# 869        4297                   ULB24
# 870        4297                   ULB24
# 871        4297                   ULB24
# 872        4297                   ULB24
# 873        4297                   ULB24
# 874        4297                   ULB24
# 875        4297                   ULB24
# 876        4297                   ULB24
# 877        4297                   ULB24
# 878        4297                   ULB24
# 879        4297                   ULB24
# 880        4297                   ULB24
# 881        4297                   ULB24
# 882        4297                   ULB24
# 883        4297                   ULB24
# 884        4297                   ULB24
# 885        4297                   ULB24
# 886        4297                   ULB24
# 887        4297                   ULB24
# 888        4297                   ULB24
# 889        4297                   ULB24
# 890        4297                   ULB24
# 891        4297                   ULB24
# 892        4297                   ULB24
# 893        4297                   ULB24
# 894        4305                     V23
# 895        4305                     V23
# 896        4305                     V23
# 897        4305                     V23
# 898        4305                     V23
# 899        4305                     V23
# 900        4311               LEGACYDUO
# 901        4311               LEGACYDUO
# 902        4311               LEGACYDUO
# 903        4311               LEGACYDUO
# 904        4311               LEGACYDUO
# 905        4311               LEGACYDUO
# 906        4311               LEGACYDUO
# 907        4311               LEGACYDUO
# 908        4311               LEGACYDUO
# 909        4311               LEGACYDUO
# 910        4311               LEGACYDUO
# 911        4311               LEGACYDUO
# 912        4311               LEGACYDUO
# 913        4311               LEGACYDUO
# 914        4311               LEGACYDUO
# 915        4311               LEGACYDUO
# 916        4311               LEGACYDUO
# 917        4311               LEGACYDUO
# 918        4311               LEGACYDUO
# 919        4311               LEGACYDUO
# 920        4311               LEGACYDUO
# 921        4311               LEGACYDUO
# 922        4311               LEGACYDUO
# 923        4311               LEGACYDUO
# 924        4311               LEGACYDUO
# 925        4311               LEGACYDUO
# 926        4311               LEGACYDUO
# 927        4311               LEGACYDUO
# 928        4311               LEGACYDUO
# 929        4311               LEGACYDUO
# 930        4311               LEGACYDUO
# 931        4311               LEGACYDUO
# 932        4311               LEGACYDUO
# 933        4311               LEGACYDUO
# 934        4311               LEGACYDUO
# 935        4311               LEGACYDUO
# 936        4311               LEGACYDUO
# 937        4311               LEGACYDUO
# 938        4311               LEGACYDUO
# 939        4311               LEGACYDUO
# 940        4311               LEGACYDUO
# 941        4311               LEGACYDUO
# 942        4311               LEGACYDUO
# 943        4311               LEGACYDUO
# 944        4311               LEGACYDUO
# 945        4311               LEGACYDUO
# 946        4311               LEGACYDUO
# 947        4311               LEGACYDUO
# 948        4311               LEGACYDUO
# 949        4311               LEGACYDUO
# 950        4311               LEGACYDUO
# 951        4311               LEGACYDUO
# 952        4311               LEGACYDUO
# 953        4311               LEGACYDUO
# 954        4311               LEGACYDUO
# 955        4311               LEGACYDUO
# 956        4311               LEGACYDUO
# 957        4313                SSTARKIT
# 958        4313                SSTARKIT
# 959        4313                SSTARKIT
# 960        4313                SSTARKIT
# 961        4313                SSTARKIT
# 962        4320                  C-1800
# 963        4321                  C-1810
# 964        4322                  C-2410
# 965        4326                  EHAW91
# 966        4326                  EHAW91
# 967        4326                  EHAW91
# 968        4326                  EHAW91
# 969        4327                  EHAW92
# 970        4327                  EHAW92
# 971        4327                  EHAW92
# 972        4327                  EHAW92
# 973        4327                  EHAW92
# 974        4337                 SSTARSC
# 975        4337                 SSTARSC
# 976        4337                 SSTARSC
# 977        4337                 SSTARSC
# 978        4337                 SSTARSC
# 979        4349                  ENFSGS
# 980        4349                  ENFSGS
# 981        4349                  ENFSGS
# 982        4349                  ENFSGS
# 983        4349                  ENFSGS
# 984        4349                  ENFSGS
# 985        4349                  ENFSGS
# 986        4351                    R316
# 987        4351                    R316
# 988        4351                    R316
# 989        4351                    R316
# 990        4351                    R316
# 991        4351                    R316
# 992        4351                    R316
# 993        4351                    R316
# 994        4351                    R316
# 995        4351                    R316
# 996        4351                    R316
# 997        4351                    R316
# 998        4351                    R316
# 999        4351                    R316
# 1000       4352                    R416
# 1001       4352                    R416
# 1002       4352                    R416
# 1003       4352                    R416
# 1004       4352                    R416
# 1005       4352                    R416
# 1006       4352                    R416
# 1007       4352                    R416
# 1008       4352                    R416
# 1009       4352                    R416
# 1010       4352                    R416
# 1011       4352                    R416
# 1012       4352                    R416
# 1013       4352                    R416
# 1014       4352                    R416
# 1015       4373              EBEACON360
# 1016       4373              EBEACON360
# 1017       4373              EBEACON360
# 1018       4373              EBEACON360
# 1019       4378                CW0BAAAA
# 1020       4378                CW0BAAAA
# 1021       4378                CW0BAAAA
# 1022       4378                CW0BAAAA
# 1023       4378                CW0BAAAA
# 1024       4378                CW0BAAAA
# 1025       4378                CW0BAAAA
# 1026       4378                CW0BAAAA
# 1027       4378                CW0BAAAA
# 1028       4386                   ENFLB
# 1029       4386                   ENFLB
# 1030       4386                   ENFLB
# 1031       4386                   ENFLB
# 1032       4386                   ENFLB
# 1033       4386                   ENFLB
# 1034       4386                   ENFLB
# 1035       4386                   ENFLB
# 1036       4413              LEGACYSOLO
# 1037       4413              LEGACYSOLO
# 1038       4413              LEGACYSOLO
# 1039       4413              LEGACYSOLO
# 1040       4413              LEGACYSOLO
# 1041       4413              LEGACYSOLO
# 1042       4413              LEGACYSOLO
# 1043       4413              LEGACYSOLO
# 1044       4413              LEGACYSOLO
# 1045       4413              LEGACYSOLO
# 1046       4413              LEGACYSOLO
# 1047       4413              LEGACYSOLO
# 1048       4413              LEGACYSOLO
# 1049       4413              LEGACYSOLO
# 1050       4413              LEGACYSOLO
# 1051       4413              LEGACYSOLO
# 1052       4413              LEGACYSOLO
# 1053       4413              LEGACYSOLO
# 1054       4413              LEGACYSOLO
# 1055       4413              LEGACYSOLO
# 1056       4413              LEGACYSOLO
# 1057       4413              LEGACYSOLO
# 1058       4413              LEGACYSOLO
# 1059       4413              LEGACYSOLO
# 4383                               6146              0       0

# %% [markdown]
# ## Exporting Options Df to CSV

# %%
filtered_df.to_csv('All_Options.csv')

# %% [markdown]
# # Filter by more than 8
#
# Here we are getting the products on the website with more than 8 options for inventory purposes.

# %%
import pandas as pd

# Assuming df_options_ is your DataFrame
# Replace 'catalogid_column_name' with the actual column name containing catalogid
# Replace 'sorting_column_name' with the actual column name containing sorting values

catalogid_column_name = 'CatalogID'
sorting_column_name = 'OptionSorting'

# Create variables to store the catalogids with up to 8 unique values
catalogids_with_up_to_8_unique_options = []

# Iterate through unique catalogids in the DataFrame
for catalogid in Products_Options_onWebsite[catalogid_column_name].unique():
    # Filter DataFrame for the current catalogid
    catalogid_data = Products_Options_onWebsite[Products_Options_onWebsite[catalogid_column_name] == catalogid]

    # Count the number of unique sorting values
    unique_sorting_count = len(catalogid_data[sorting_column_name].unique())

    # Check if the current catalogid has up to 8 unique values
    if unique_sorting_count > 8:
        catalogids_with_up_to_8_unique_options.append(catalogid)

# Filter the original DataFrame based on the selected catalogids
filtered_over_8 = Products_Options_onWebsite[Products_Options_onWebsite[catalogid_column_name].isin(catalogids_with_up_to_8_unique_options)]

# Print or use the filtered_df as needed
filtered_over_8.head(100)
# Out:
#       CatalogID        SKU                                     Name  \
# 311        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 312        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 313        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 314        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 315        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 316        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 317        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 318        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 319        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 320        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 321        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 322        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 323        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 324        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 325        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 326        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 327        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 328        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 329        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 330        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 331        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 332        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 333        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 334        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 335        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 336        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 337        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 338        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 339        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 340        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 341        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 342        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 343        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 344        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 345        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 346        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 347        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 348        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 349        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 350        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 351        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 352        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 353        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 354        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 355        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 356        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 357        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 358        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 359        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 360        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 361        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 362        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 363        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 364        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 365        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 366        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 367        3817  970L-4908         Tomar 970L Scorpion 49" Lightbar
# 2145       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2146       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2147       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2148       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2149       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2150       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2151       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2152       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2153       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2154       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2155       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2156       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2157       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2158       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2159       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2160       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2161       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2162       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2163       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2164       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2165       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2166       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2167       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2168       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2169       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2170       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2171       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2172       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2173       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2174       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2175       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2176       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2177       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2178       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2179       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2180       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2181       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2182       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2183       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2184       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2185       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2186       5938        FS-  Feniex Fusion S Front Interior Lightbar
# 2187       5938        FS-  Feniex Fusion S Front Interior Lightbar
#
#       NotForSale   Hide                            OptionName  \
# 311        False  False                                  Blue
# 312        False  False                                   Red
# 313        False  False                                 Amber
# 314        False  False                                   Red
# 315        False  False                                 Amber
# 316        False  False                                  Blue
# 317        False  False                                  Blue
# 318        False  False                              Red/Blue
# 319        False  False                                 White
# 320        False  False                                  None
# 321        False  False                                 Amber
# 322        False  False                                   Red
# 323        False  False                                  None
# 324        False  False                                 Amber
# 325        False  False                                   Red
# 326        False  False                                  Blue
# 327        False  False                              Red/Blue
# 328        False  False                                 White
# 329        False  False                                  Blue
# 330        False  False                              Red/Blue
# 331        False  False                                 White
# 332        False  False                                  None
# 333        False  False                                 Amber
# 334        False  False                                   Red
# 335        False  False                                  None
# 336        False  False                                 Amber
# 337        False  False                                   Red
# 338        False  False                                  Blue
# 331                -W         2865              5       0
# 332             -NONE         2865              5       0
# 333                -A         2865              5       0
# 334                -R         2865              5       0
# 335             -NONE         2866              6       0
# 336                -A         2866              6       0
# 337                -R         2866              6       0
# 338                -B         2866              6       0
# 339               -RB         2866              6       0
# 340                -W         2866              6       0
# 341                -B         2867              7       0
# 342               -RB         2867              7       0
# 343                -W         2867              7       0
# 344             -NONE         2867              7       0
# 345                -A         2867              7       0
# 346                -R         2867              7       0
# 347             -NONE         2868              8       0
# 348                -A         2868              8       0
# 349                -R         2868              8       0
# 350                -B         2868              8       0
# 351               -RB         2868              8       0
# 352                -W         2868              8       0
# 353            -HILED         2869             10       0
# 354             -NONE         2869             10       0
# 355              -LED         2869             10       0
# 356             -HALO         2869             10       0
# 357                           2870              0       0
# 358             -NONE         2871              9       0
# 359                -A         2871              9       0
# 360                -R         2871              9       0
# 361                -B         2871              9       0
# 362               -RB         2871              9       0
# 363                -W         2871              9       0
# 364             -NONE         2872             11       0
# 365             -HALO         2872             11       0
# 366            -HILED         2872             11       0
# 367              -LED         2872             11       0
# 2145             -309         4696              2       1
# 2146             -609         4696              2       0
# 2147             -811         4696              2       0
# 2148             -909         4696              2       1
# 2149             -910         4696              2       0
# 2150             -910         4696              2       0
# 2151            -1311         4696              2       1
# 2152            -1311         4696              2       1
# 2153            -1409         4696              2       0
# 2154            -1409         4696              2       0
# 2155            -1518         4696              2       0
# 2156            -1518         4696              2       0
# 2157            -1518         4696              2       0
# 2158            -1518         4696              2       0
# 2159            -1809         4696              2       1
# 2160            -1915         4696              2       0
# 2161            -1519         4696              2       0
# 2162            -3117         4696              2       0
# 2163             -421         4696              2       0
# 2164            -1419         4696              2       0
# 2165            -1521         4696              2       0
# 2166                A         5764              3       0
# 2167                B         5764              3       0
# 2168                G         5764              3       0
# 2169                R         5764              3       0
# 2170                W         5764              3       0
# 2171               TD         5764              3       0
# 2172                A         5765              4       0
# 2173                B         5765              4       0
# 2174                G         5765              4       0
# 2175                R         5765              4       0
# 2176                W         5765              4       0
# 2177               TD         5765              4       0
# 2178                A         5766              5       0
# 2179                B         5766              5       0
# 2180                G         5766              5       0
# 2181                R         5766              5       0
# 2182                W         5766              5       0
# 2183               TD         5766              5       0
# 2184                A         5767              6       0
# 2185                B         5767              6       0
# 2186                G         5767              6       0
# 2187                R         5767              6       0

# %%
filtered_over_8 = filtered_over_8[['CatalogID','SKU','Name','OptionName','OptionPartNumber']]
filtered_over_8.to_csv('SKUs_OverEightOPtions_onWebsite.csv')

# %% [markdown]
# The code below added this short list to all the products without options.

# %%
len(AllSKUs_No_Options['CatalogID'].unique())
# Out:
# 783

# %% [markdown]
# # Just in case - No Options Products on Website
#
# Here another CSV is exported as a list of the products with no options that are just on the website. Client requested all products without options, this is an extra step so that they do not need to check if it is or is not on the website.

# %%
AllSKUs_No_Options_onwebsite = AllSKUs_No_Options[AllSKUs_No_Options['Hide'] == False]

# %%
AllSKUs_No_Options_onwebsite.to_csv('SKUs_No_Options_OnWebsite.csv')
